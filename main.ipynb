# %% [markdown]
# # Musical instrument sound classification from Audio

# %% [markdown]
# #### This cell block will contain all the import statements

# %%
#General
import numpy as np
import itertools
import pandas as pd
import math
import os
import IPython
os.environ['NUMBA_CACHE_DIR'] = IPython.paths.get_ipython_cache_dir()

# System
import os, fnmatch

# Visualization
import matplotlib.pyplot as plt
from IPython.core.display import HTML, display, Image
from IPython.display import Audio

# Machine Learning
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import confusion_matrix, f1_score, classification_report
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score, classification_report

# Deep Learning
import tensorflow as tf
from tensorflow.python.client import device_lib 
from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization,MaxPooling2D, Dense, Dropout,Flatten, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import History, EarlyStopping, ModelCheckpoint, TensorBoard  # Ensure TensorBoard is imported
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.models import load_model

# Audio
import librosa.display
from librosa.util import normalize as normalize
import IPython.display as ipd
import librosa
import librosa.display

# Random Seed
# Set random seed for TensorFlow
tf.random.set_seed(0)

# Set random seed for numpy
np.random.seed(0)

# Configurations
path='./audio/'

# Display CPUs and GPUs
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10950407304610151574
# xla_global_id: -1
# ]
# C:\Windows\Temp\ipykernel_66344\2497090275.py:16: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display, Image

# %% [markdown]
# #### Here are some parameters required for signal processing and machine learning

# %%
# Signal Processing Parameters
fs = 44100         # Sampling Frequency
n_fft = 2048       # length of the FFT window
hop_length = 512   # Number of samples between successive frames

# Machine Learning Parameters
testset_size = 0.25 #Percentage of data for Testing

# %% [markdown]
# #### In this cell the code iterates over all the `.mp3` files in the specified directory (`path`) and its subdirectories. For each file, it extracts its file path, determines its label based on predefined instrument classes, trims silence, calculates its duration, and stores the file path, label, and duration in separate lists (`files`, `labels`, `duration`). Additionally, if a file fails to load or has insufficient data, it prints an error message and continues to the next file. Finally, it prints the total number of audio files found along with their paths, labels, and durations.
#
# #### this is the datasetlink I got all the dataset and i have selected few of the orchestral instrument from this dataset https://philharmonia.co.uk/resources/sound-samples/

# %%
files = []
labels = []
duration = []
classes = ['contrabassoon','flute', 'sax', 'oboe', 'cello', 'trumpet', 'viola','mandolin']

for root, dirnames, filenames in os.walk(path):
    for i, filename in enumerate(fnmatch.filter(filenames, '*.mp3')):
        file_path = os.path.join(root, filename)
        files.append(file_path)
        matched = False
        for name in classes:
            if fnmatch.fnmatchcase(filename, '*' + name + '*'):
                labels.append(name)
                matched = True
                break
        if not matched:
            labels.append('other')
        
        print(f"Get {i+1} = {filename}")
        try:
            y, sr = librosa.load(file_path, sr=fs)
            if len(y) < 2:
                print(f"Error loading {filename}: insufficient data")
                continue
            yt, index = librosa.effects.trim(y, top_db=60)  # Trim silence
            duration.append(librosa.get_duration(y = yt, sr=fs))
        except Exception as e:
            print(f"Error loading {filename}. Error: {e}")

print(f"Found {len(files)} audio files in {path}")
# Out:
# Get 1 = cello_A2_025_forte_arco-normal.mp3
# Get 2 = cello_A2_025_fortissimo_arco-normal.mp3
# Get 3 = cello_A2_025_mezzo-forte_arco-col-legno-battuto.mp3
# Get 4 = cello_A2_025_mezzo-piano_arco-normal.mp3
# Get 5 = cello_A2_025_pianissimo_arco-normal.mp3
# Get 6 = cello_A2_05_forte_arco-normal.mp3
# Get 7 = cello_A2_05_fortissimo_arco-normal.mp3
# Get 8 = cello_A2_05_mezzo-piano_arco-normal.mp3
# Get 9 = cello_A2_05_pianissimo_arco-normal.mp3
# Get 10 = cello_A2_15_forte_arco-normal.mp3
# Get 11 = cello_A2_15_pianissimo_arco-normal.mp3
# Get 12 = cello_A2_15_piano_arco-normal.mp3
# Get 13 = cello_A2_1_forte_arco-normal.mp3
# Get 14 = cello_A2_1_fortissimo_arco-normal.mp3
# Get 15 = cello_A2_1_mezzo-piano_arco-normal.mp3
# Get 16 = cello_A2_1_mezzo-piano_non-vibrato.mp3
# Get 17 = cello_A2_1_pianissimo_arco-normal.mp3
# Get 18 = cello_A3_025_forte_arco-normal.mp3
# Get 19 = cello_A3_025_fortissimo_arco-normal.mp3
# Get 20 = cello_A3_025_mezzo-forte_arco-col-legno-battuto.mp3
# Get 21 = cello_A3_025_mezzo-piano_arco-normal.mp3
# Get 22 = cello_A3_025_pianissimo_arco-normal.mp3
# Get 23 = cello_A3_05_forte_arco-normal.mp3
# Get 24 = cello_A3_05_fortissimo_arco-normal.mp3
# Get 25 = cello_A3_05_mezzo-piano_arco-normal.mp3
# Get 26 = cello_A3_15_forte_arco-normal.mp3
# Get 27 = cello_A3_15_mezzo-piano_arco-normal.mp3
# Get 28 = cello_A3_1_forte_arco-normal.mp3
# Get 29 = cello_A3_1_fortissimo_arco-normal.mp3
# Get 30 = cello_A3_1_mezzo-piano_arco-minor-trill.mp3
# Get 31 = cello_A3_1_mezzo-piano_arco-normal.mp3
# Get 32 = cello_A3_1_mezzo-piano_non-vibrato.mp3
# Get 33 = cello_A3_1_pianissimo_arco-normal.mp3
# Get 34 = cello_A4_025_forte_arco-normal.mp3
# Get 35 = cello_A4_025_fortissimo_arco-normal.mp3
# Get 36 = cello_A4_025_mezzo-forte_arco-col-legno-battuto.mp3
# Get 37 = cello_A4_025_mezzo-piano_arco-normal.mp3
# Get 38 = cello_A4_025_pianissimo_arco-normal.mp3
# Get 39 = cello_A4_05_forte_arco-normal.mp3
# Get 40 = cello_A4_05_mezzo-piano_arco-normal.mp3
# Get 41 = cello_A4_05_pianissimo_arco-normal.mp3
# Get 42 = cello_A4_15_forte_arco-normal.mp3
# Get 43 = cello_A4_15_mezzo-piano_arco-normal.mp3
# Get 44 = cello_A4_1_forte_arco-normal.mp3
# Get 45 = cello_A4_1_fortissimo_arco-normal.mp3
# Get 46 = cello_A4_1_mezzo-forte_arco-harmonic.mp3
# Get 47 = cello_A4_1_mezzo-piano_arco-minor-trill.mp3
# Get 48 = cello_A4_1_mezzo-piano_arco-normal.mp3
# Get 49 = cello_A4_1_mezzo-piano_molto-vibrato.mp3
# Get 50 = cello_A4_1_pianissimo_arco-normal.mp3
# Get 51 = cello_Gs2_025_pianissimo_arco-normal.mp3
# Get 52 = cello_Gs3_025_forte_arco-normal.mp3
# Get 53 = cello_Gs3_025_fortissimo_arco-normal.mp3
# Get 54 = cello_Gs3_025_mezzo-piano_arco-normal.mp3
# Get 55 = cello_Gs3_025_pianissimo_arco-normal.mp3
# Get 56 = cello_Gs3_05_forte_arco-normal.mp3
# Get 57 = cello_Gs3_05_fortissimo_arco-normal.mp3
# Get 58 = cello_Gs3_05_mezzo-piano_arco-normal.mp3
# Get 59 = cello_Gs3_05_pianissimo_arco-normal.mp3
# Get 60 = cello_Gs3_15_forte_arco-normal.mp3
# Get 61 = cello_Gs3_15_fortissimo_arco-normal.mp3
# Get 62 = cello_Gs3_15_pianissimo_arco-normal.mp3
# Get 63 = cello_Gs3_15_piano_arco-normal.mp3
# Get 64 = cello_Gs3_1_forte_arco-normal.mp3
# Get 65 = cello_Gs3_1_mezzo-piano_arco-normal.mp3
# Get 66 = cello_Gs3_1_pianissimo_arco-normal.mp3
# Get 67 = cello_Gs4_025_forte_arco-normal.mp3
# Get 68 = cello_Gs4_025_fortissimo_arco-normal.mp3
# Get 69 = cello_Gs4_025_mezzo-forte_arco-col-legno-battuto.mp3
# Get 70 = cello_Gs4_025_mezzo-piano_arco-normal.mp3
# Get 71 = cello_Gs4_025_pianissimo_arco-normal.mp3
# Get 72 = cello_Gs4_05_forte_arco-normal.mp3
# Get 73 = cello_Gs4_05_fortissimo_arco-normal.mp3
# Get 74 = cello_Gs4_05_mezzo-piano_arco-normal.mp3
# Get 75 = cello_Gs4_05_pianissimo_arco-normal.mp3
# Get 76 = cello_Gs4_15_forte_arco-normal.mp3
# Get 77 = cello_Gs4_15_fortissimo_arco-normal.mp3
# Get 78 = cello_Gs4_15_mezzo-piano_arco-normal.mp3
# Get 79 = cello_Gs4_15_pianissimo_arco-normal.mp3
# Get 80 = cello_Gs4_1_forte_arco-normal.mp3
# Get 81 = cello_Gs4_1_fortissimo_arco-normal.mp3
# Get 82 = cello_Gs4_1_mezzo-piano_arco-normal.mp3
# Get 83 = cello_Gs4_1_pianissimo_arco-normal.mp3
# Get 84 = cello_Gs5_025_forte_arco-normal.mp3
# Get 85 = cello_Gs5_025_fortissimo_arco-normal.mp3
# Get 86 = cello_Gs5_025_mezzo-piano_arco-normal.mp3
# Get 87 = cello_Gs5_025_pianissimo_arco-normal.mp3
# Get 88 = cello_Gs5_05_forte_arco-normal.mp3
# Get 89 = cello_Gs5_05_fortissimo_arco-normal.mp3
# Get 90 = cello_Gs5_05_mezzo-piano_arco-normal.mp3
# Get 91 = cello_Gs5_05_pianissimo_arco-normal.mp3
# Get 92 = cello_Gs5_15_forte_arco-normal.mp3
# Get 93 = cello_Gs5_15_fortissimo_arco-normal.mp3
# Get 94 = cello_Gs5_15_mezzo-piano_arco-normal.mp3
# Get 95 = cello_Gs5_15_pianissimo_arco-normal.mp3
# Get 96 = cello_Gs5_1_forte_arco-normal.mp3
# Get 97 = cello_Gs5_1_fortissimo_arco-normal.mp3
# Get 98 = cello_Gs5_1_mezzo-forte_arco-harmonic.mp3
# Get 99 = cello_Gs5_1_mezzo-piano_arco-normal.mp3
# Get 100 = cello_Gs5_1_pianissimo_arco-normal.mp3
# Get 1 = contrabassoon_A1_025_forte_normal.mp3
# Get 2 = contrabassoon_A1_025_fortissimo_normal.mp3
# Get 3 = contrabassoon_A1_025_mezzo-forte_normal.mp3
# Get 4 = contrabassoon_A1_05_forte_normal.mp3
# Get 5 = contrabassoon_A1_05_fortissimo_normal.mp3
# Get 6 = contrabassoon_A1_05_mezzo-forte_normal.mp3
# Get 7 = contrabassoon_A1_15_forte_normal.mp3
# Get 8 = contrabassoon_A1_15_fortissimo_normal.mp3
# Get 9 = contrabassoon_A1_15_mezzo-forte_normal.mp3
# Get 10 = contrabassoon_A1_15_piano_normal.mp3
# Get 11 = contrabassoon_A1_1_forte_normal.mp3
# Get 12 = contrabassoon_A1_1_fortissimo_normal.mp3
# Get 13 = contrabassoon_A1_1_mezzo-forte_normal.mp3
# Get 14 = contrabassoon_A1_1_piano_normal.mp3
# Get 15 = contrabassoon_A2_025_forte_normal.mp3
# Get 16 = contrabassoon_A2_025_mezzo-forte_normal.mp3
# Get 17 = contrabassoon_A2_05_forte_normal.mp3
# Get 18 = contrabassoon_A2_05_mezzo-forte_normal.mp3
# Get 19 = contrabassoon_A2_15_forte_normal.mp3
# Get 20 = contrabassoon_A2_15_fortissimo_normal.mp3
# Get 21 = contrabassoon_A2_15_mezzo-forte_normal.mp3
# Get 22 = contrabassoon_A2_15_piano_normal.mp3
# Get 23 = contrabassoon_A2_1_forte_normal.mp3
# Get 24 = contrabassoon_A2_1_fortissimo_normal.mp3
# Get 25 = contrabassoon_A2_1_mezzo-forte_normal.mp3
# Get 26 = contrabassoon_A2_1_piano_normal.mp3
# Get 27 = contrabassoon_A3_025_forte_normal.mp3
# Get 28 = contrabassoon_A3_025_fortissimo_normal.mp3
# Get 29 = contrabassoon_A3_025_mezzo-forte_normal.mp3
# Get 30 = contrabassoon_A3_025_piano_normal.mp3
# Get 31 = contrabassoon_A3_05_forte_normal.mp3
# Get 32 = contrabassoon_A3_05_fortissimo_normal.mp3
# Get 33 = contrabassoon_A3_05_mezzo-forte_normal.mp3
# Get 34 = contrabassoon_A3_05_piano_normal.mp3
# Get 35 = contrabassoon_A3_15_forte_normal.mp3
# Get 36 = contrabassoon_A3_15_fortissimo_normal.mp3
# Get 37 = contrabassoon_A3_15_mezzo-forte_normal.mp3
# Get 38 = contrabassoon_A3_15_piano_normal.mp3
# Get 39 = contrabassoon_A3_1_forte_normal.mp3
# Get 40 = contrabassoon_A3_1_fortissimo_normal.mp3
# Get 41 = contrabassoon_A3_1_mezzo-forte_normal.mp3
# Get 42 = contrabassoon_A3_1_piano_normal.mp3
# Get 43 = contrabassoon_A3_very-long_forte_normal.mp3
# Get 44 = contrabassoon_A3_very-long_piano_normal.mp3
# Get 45 = contrabassoon_As0_025_forte_normal.mp3
# Get 46 = contrabassoon_As0_025_mezzo-forte_normal.mp3
# Get 47 = contrabassoon_As0_05_forte_normal.mp3
# Get 48 = contrabassoon_As0_05_mezzo-forte_normal.mp3
# Get 49 = contrabassoon_As0_15_forte_normal.mp3
# Get 50 = contrabassoon_As0_15_fortissimo_normal.mp3
# Get 51 = contrabassoon_As0_15_mezzo-forte_normal.mp3
# Get 52 = contrabassoon_As0_1_forte_normal.mp3
# Get 53 = contrabassoon_As0_1_fortissimo_normal.mp3
# Get 54 = contrabassoon_As0_1_mezzo-forte_normal.mp3
# Get 55 = contrabassoon_As0_long_forte_major-trill.mp3
# Get 56 = contrabassoon_As0_long_forte_tremolo.mp3
# Get 57 = contrabassoon_As0_phrase_mezzo-forte_legato.mp3
# Get 58 = contrabassoon_As0_phrase_mezzo-forte_nonlegato.mp3
# Get 59 = contrabassoon_As0_phrase_mezzo-forte_staccatissimo.mp3
# Get 60 = contrabassoon_As0_phrase_mezzo-forte_staccato.mp3
# Get 61 = contrabassoon_As0_phrase_mezzo-forte_tenuto.mp3
# Get 62 = contrabassoon_As0_phrase_mezzo-forte_tongued-slur.mp3
# Get 63 = contrabassoon_As0_very-long_cresc-decresc_normal.mp3
# Get 64 = contrabassoon_As1_025_forte_normal.mp3
# Get 65 = contrabassoon_As1_025_fortissimo_normal.mp3
# Get 66 = contrabassoon_As1_025_mezzo-forte_normal.mp3
# Get 67 = contrabassoon_As1_025_piano_normal.mp3
# Get 68 = contrabassoon_As1_05_forte_normal.mp3
# Get 69 = contrabassoon_As1_05_fortissimo_normal.mp3
# Get 70 = contrabassoon_As1_05_mezzo-forte_normal.mp3
# Get 71 = contrabassoon_As1_05_piano_normal.mp3
# Get 72 = contrabassoon_As1_15_forte_normal.mp3
# Get 73 = contrabassoon_As1_15_fortissimo_normal.mp3
# Get 74 = contrabassoon_As1_15_mezzo-forte_normal.mp3
# Get 75 = contrabassoon_As1_15_piano_normal.mp3
# Get 76 = contrabassoon_As1_1_forte_normal.mp3
# Get 77 = contrabassoon_As1_1_fortissimo_normal.mp3
# Get 78 = contrabassoon_As1_1_mezzo-forte_normal.mp3
# Get 79 = contrabassoon_As1_1_piano_normal.mp3
# Get 80 = contrabassoon_As1_phrase_mezzo-forte_legato.mp3
# Get 81 = contrabassoon_As1_phrase_mezzo-forte_nonlegato.mp3
# Get 82 = contrabassoon_As1_phrase_mezzo-forte_staccatissimo.mp3
# Get 83 = contrabassoon_As1_phrase_mezzo-forte_staccato.mp3
# Get 84 = contrabassoon_As1_phrase_mezzo-forte_tenuto.mp3
# Get 85 = contrabassoon_As1_phrase_mezzo-forte_tongued-slur.mp3
# Get 86 = contrabassoon_As1_very-long_cresc-decresc_normal.mp3
# Get 87 = contrabassoon_As2_025_forte_normal.mp3
# Get 88 = contrabassoon_As2_05_forte_normal.mp3
# Get 89 = contrabassoon_As2_05_fortissimo_normal.mp3
# Get 90 = contrabassoon_As2_05_mezzo-forte_normal.mp3
# Get 91 = contrabassoon_As2_05_piano_normal.mp3
# Get 92 = contrabassoon_As2_15_forte_normal.mp3
# Get 93 = contrabassoon_As2_15_fortissimo_normal.mp3
# Get 94 = contrabassoon_As2_15_mezzo-forte_normal.mp3
# Get 95 = contrabassoon_As2_15_piano_normal.mp3
# Get 96 = contrabassoon_As2_1_forte_fluttertonguing.mp3
# Get 97 = contrabassoon_As2_1_forte_normal.mp3
# Get 98 = contrabassoon_As2_1_fortissimo_normal.mp3
# Get 99 = contrabassoon_As2_1_mezzo-forte_normal.mp3
# Get 100 = contrabassoon_As2_1_piano_normal.mp3
# Get 1 = flute_A4_025_forte_normal.mp3
# Get 2 = flute_A4_025_mezzo-forte_normal.mp3
# Get 3 = flute_A4_025_mezzo-piano_normal.mp3
# Get 4 = flute_A4_025_pianissimo_normal.mp3
# Get 5 = flute_A4_025_piano_normal.mp3
# Get 6 = flute_A4_05_forte_normal.mp3
# Get 7 = flute_A4_05_mezzo-forte_normal.mp3
# Get 8 = flute_A4_05_mezzo-piano_normal.mp3
# Get 9 = flute_A4_05_pianissimo_normal.mp3
# Get 10 = flute_A4_05_piano_normal.mp3
# Get 11 = flute_A4_15_forte_normal.mp3
# Get 12 = flute_A4_15_mezzo-forte_normal.mp3
# Get 13 = flute_A4_15_mezzo-piano_normal.mp3
# Get 14 = flute_A4_15_pianissimo_normal.mp3
# Get 15 = flute_A4_15_piano_normal.mp3
# Get 16 = flute_A4_1_forte_normal.mp3
# Get 17 = flute_A4_1_mezzo-forte_normal.mp3
# Get 18 = flute_A4_1_mezzo-piano_normal.mp3
# Get 19 = flute_A4_1_pianissimo_normal.mp3
# Get 20 = flute_A4_1_piano_normal.mp3
# Get 21 = flute_A5_025_forte_normal.mp3
# Get 22 = flute_A5_025_mezzo-forte_normal.mp3
# Get 23 = flute_A5_025_mezzo-piano_normal.mp3
# Get 24 = flute_A5_025_pianissimo_normal.mp3
# Get 25 = flute_A5_025_piano_normal.mp3
# Get 26 = flute_A5_05_forte_normal.mp3
# Get 27 = flute_A5_05_mezzo-forte_normal.mp3
# Get 28 = flute_A5_05_mezzo-piano_normal.mp3
# Get 29 = flute_A5_05_pianissimo_normal.mp3
# Get 30 = flute_A5_05_piano_normal.mp3
# Get 31 = flute_A5_15_forte_normal.mp3
# Get 32 = flute_A5_15_mezzo-forte_normal.mp3
# Get 33 = flute_A5_15_mezzo-piano_normal.mp3
# Get 34 = flute_A5_15_pianissimo_normal.mp3
# Get 35 = flute_A5_15_piano_normal.mp3
# Get 36 = flute_A5_1_forte_normal.mp3
# Get 37 = flute_A5_1_mezzo-forte_normal.mp3
# Get 38 = flute_A5_1_mezzo-piano_normal.mp3
# Get 39 = flute_A5_1_pianissimo_normal.mp3
# Get 40 = flute_A5_1_piano_normal.mp3
# Get 41 = flute_A6_05_forte_normal.mp3
# Get 42 = flute_A6_05_mezzo-forte_normal.mp3
# Get 43 = flute_A6_05_pianissimo_normal.mp3
# Get 44 = flute_A6_05_piano_normal.mp3
# Get 45 = flute_A6_15_forte_normal.mp3
# Get 46 = flute_A6_1_forte_normal.mp3
# Get 47 = flute_A6_1_fortissimo_minor-trill.mp3
# Get 48 = flute_A6_1_mezzo-forte_normal.mp3
# Get 49 = flute_A6_1_pianissimo_normal.mp3
# Get 50 = flute_A6_1_piano_normal.mp3
# Get 51 = flute_Gs4_025_forte_normal.mp3
# Get 52 = flute_Gs4_025_mezzo-forte_normal.mp3
# Get 53 = flute_Gs4_025_mezzo-piano_normal.mp3
# Get 54 = flute_Gs4_025_pianissimo_normal.mp3
# Get 55 = flute_Gs4_025_piano_normal.mp3
# Get 56 = flute_Gs4_05_forte_normal.mp3
# Get 57 = flute_Gs4_05_mezzo-forte_normal.mp3
# Get 58 = flute_Gs4_05_mezzo-piano_normal.mp3
# Get 59 = flute_Gs4_05_pianissimo_normal.mp3
# Get 60 = flute_Gs4_05_piano_normal.mp3
# Get 61 = flute_Gs4_15_forte_normal.mp3
# Get 62 = flute_Gs4_15_mezzo-forte_normal.mp3
# Get 63 = flute_Gs4_15_mezzo-piano_normal.mp3
# Get 64 = flute_Gs4_15_pianissimo_normal.mp3
# Get 65 = flute_Gs4_15_piano_normal.mp3
# Get 66 = flute_Gs5_025_forte_normal.mp3
# Get 67 = flute_Gs5_025_mezzo-forte_normal.mp3
# Get 68 = flute_Gs5_025_mezzo-piano_normal.mp3
# Get 69 = flute_Gs5_025_pianissimo_normal.mp3
# Get 70 = flute_Gs5_025_piano_normal.mp3
# Get 71 = flute_Gs5_05_forte_normal.mp3
# Get 72 = flute_Gs5_05_mezzo-forte_normal.mp3
# Get 73 = flute_Gs5_05_mezzo-piano_normal.mp3
# Get 74 = flute_Gs5_05_pianissimo_normal.mp3
# Get 75 = flute_Gs5_05_piano_normal.mp3
# Get 76 = flute_Gs5_15_forte_normal.mp3
# Get 77 = flute_Gs5_15_mezzo-forte_normal.mp3
# Get 78 = flute_Gs5_15_mezzo-piano_normal.mp3
# Get 79 = flute_Gs5_15_piano_normal.mp3
# Get 80 = flute_Gs5_1_forte_normal.mp3
# Get 81 = flute_Gs5_1_mezzo-forte_normal.mp3
# Get 82 = flute_Gs5_1_mezzo-piano_normal.mp3
# Get 83 = flute_Gs5_1_pianissimo_normal.mp3
# Get 84 = flute_Gs5_1_piano_normal.mp3
# Get 85 = flute_Gs6_025_forte_normal.mp3
# Get 86 = flute_Gs6_025_mezzo-forte_normal.mp3
# Get 87 = flute_Gs6_025_pianissimo_normal.mp3
# Get 88 = flute_Gs6_025_piano_normal.mp3
# Get 89 = flute_Gs6_05_forte_normal.mp3
# Get 90 = flute_Gs6_05_mezzo-forte_normal.mp3
# Get 91 = flute_Gs6_05_pianissimo_normal.mp3
# Get 92 = flute_Gs6_05_piano_normal.mp3
# Get 93 = flute_Gs6_15_forte_normal.mp3
# Get 94 = flute_Gs6_15_mezzo-forte_normal.mp3
# Get 95 = flute_Gs6_15_pianissimo_normal.mp3
# Get 96 = flute_Gs6_15_piano_normal.mp3
# Get 97 = flute_Gs6_1_forte_normal.mp3
# Get 98 = flute_Gs6_1_mezzo-forte_normal.mp3
# Get 99 = flute_Gs6_1_pianissimo_normal.mp3
# Get 100 = flute_Gs6_1_piano_normal.mp3
# Get 1 = mandolin_A3_very-long_forte_tremolo.mp3
# Get 2 = mandolin_A3_very-long_piano_normal.mp3
# Get 3 = mandolin_A4_very-long_forte_tremolo.mp3
# Get 4 = mandolin_A4_very-long_piano_normal.mp3
# Get 5 = mandolin_A4_very-long_piano_tremolo.mp3
# Get 6 = mandolin_A5_very-long_forte_tremolo.mp3
# Get 7 = mandolin_A5_very-long_piano_normal.mp3
# Get 8 = mandolin_A6_very-long_piano_normal.mp3
# Get 9 = mandolin_A6_very-long_piano_tremolo.mp3
# Get 10 = mandolin_As3_very-long_forte_tremolo.mp3
# Get 11 = mandolin_As3_very-long_piano_normal.mp3
# Get 12 = mandolin_As4_very-long_piano_normal.mp3
# Get 13 = mandolin_As4_very-long_piano_tremolo.mp3
# Get 14 = mandolin_As5_very-long_piano_normal.mp3
# Get 15 = mandolin_As5_very-long_piano_tremolo.mp3
# Get 16 = mandolin_B3_very-long_piano_normal.mp3
# Get 17 = mandolin_B3_very-long_piano_tremolo.mp3
# Get 18 = mandolin_B4_very-long_piano_normal.mp3
# Get 19 = mandolin_B4_very-long_piano_tremolo.mp3
# Get 20 = mandolin_B5_very-long_piano_normal.mp3
# Get 21 = mandolin_B5_very-long_piano_tremolo.mp3
# Get 22 = mandolin_C4_very-long_piano_normal.mp3
# Get 23 = mandolin_C4_very-long_piano_tremolo.mp3
# Get 24 = mandolin_C5_very-long_piano_normal.mp3
# Get 25 = mandolin_C5_very-long_piano_tremolo.mp3
# Get 26 = mandolin_C6_very-long_piano_normal.mp3
# Get 27 = mandolin_C6_very-long_piano_tremolo.mp3
# Get 28 = mandolin_Cs4_very-long_piano_normal.mp3
# Get 29 = mandolin_Cs4_very-long_piano_tremolo.mp3
# Get 30 = mandolin_Cs5_very-long_piano_normal.mp3
# Get 31 = mandolin_Cs5_very-long_piano_tremolo.mp3
# Get 32 = mandolin_Cs6_very-long_piano_normal.mp3
# Get 33 = mandolin_Cs6_very-long_piano_tremolo.mp3
# Get 34 = mandolin_D4_very-long_piano_normal.mp3
# Get 35 = mandolin_D4_very-long_piano_tremolo.mp3
# Get 36 = mandolin_D5_very-long_forte_tremolo.mp3
# Get 37 = mandolin_D5_very-long_piano_normal.mp3
# Get 38 = mandolin_D6_very-long_piano_normal.mp3
# Get 39 = mandolin_D6_very-long_piano_tremolo.mp3
# Get 40 = mandolin_Ds4_very-long_piano_normal.mp3
# Get 41 = mandolin_Ds4_very-long_piano_tremolo.mp3
# Get 42 = mandolin_Ds5_very-long_piano_normal.mp3
# Get 43 = mandolin_Ds5_very-long_piano_tremolo.mp3
# Get 44 = mandolin_Ds6_very-long_piano_normal.mp3
# Get 45 = mandolin_Ds6_very-long_piano_tremolo.mp3
# Get 46 = mandolin_E4_very-long_piano_normal.mp3
# Get 47 = mandolin_E4_very-long_piano_tremolo.mp3
# Get 48 = mandolin_E5_very-long_piano_normal.mp3
# Get 49 = mandolin_E5_very-long_piano_tremolo.mp3
# Get 50 = mandolin_E6_very-long_piano_normal.mp3
# Get 51 = mandolin_E6_very-long_piano_tremolo.mp3
# Get 52 = mandolin_F4_very-long_piano_normal.mp3
# Get 53 = mandolin_F4_very-long_piano_tremolo.mp3
# Get 54 = mandolin_F5_very-long_piano_normal.mp3
# Get 55 = mandolin_F5_very-long_piano_tremolo.mp3
# Get 56 = mandolin_F6_very-long_piano_normal.mp3
# Get 57 = mandolin_F6_very-long_piano_tremolo.mp3
# Get 58 = mandolin_Fs4_very-long_piano_normal.mp3
# Get 59 = mandolin_Fs4_very-long_piano_tremolo.mp3
# Get 60 = mandolin_Fs5_very-long_piano_normal.mp3
# Get 61 = mandolin_Fs5_very-long_piano_tremolo.mp3
# Get 62 = mandolin_Fs6_very-long_piano_normal.mp3
# Get 63 = mandolin_Fs6_very-long_piano_tremolo.mp3
# Get 64 = mandolin_G3_very-long_forte_tremolo.mp3
# Get 65 = mandolin_G3_very-long_piano_normal.mp3
# Get 66 = mandolin_G3_very-long_piano_tremolo.mp3
# Get 67 = mandolin_G4_very-long_forte_tremolo.mp3
# Get 68 = mandolin_G4_very-long_piano_normal.mp3
# Get 69 = mandolin_G5_very-long_piano_normal.mp3
# Get 70 = mandolin_G5_very-long_piano_tremolo.mp3
# Get 71 = mandolin_G6_very-long_piano_normal.mp3
# Get 72 = mandolin_G6_very-long_piano_tremolo.mp3
# Get 73 = mandolin_Gs3_very-long_piano_normal.mp3
# Get 74 = mandolin_Gs3_very-long_piano_tremolo.mp3
# Get 75 = mandolin_Gs4_very-long_forte_tremolo.mp3
# Get 76 = mandolin_Gs4_very-long_piano_normal.mp3
# Get 77 = mandolin_Gs5_very-long_piano_normal.mp3
# Get 78 = mandolin_Gs5_very-long_piano_tremolo.mp3
# Get 79 = mandolin_Gs6_very-long_piano_normal.mp3
# Get 80 = mandolin_Gs6_very-long_piano_tremolo.mp3
# Get 1 = oboe_A4_025_forte_normal.mp3
# Get 2 = oboe_A4_025_fortissimo_normal.mp3
# Get 3 = oboe_A4_025_piano_normal.mp3
# Get 4 = oboe_A4_05_forte_normal.mp3
# Get 5 = oboe_A4_05_fortissimo_normal.mp3
# Get 6 = oboe_A4_05_piano_normal.mp3
# Get 7 = oboe_A4_15_forte_normal.mp3
# Get 8 = oboe_A4_15_piano_normal.mp3
# Get 9 = oboe_A4_1_forte_normal.mp3
# Get 10 = oboe_A4_1_fortissimo_normal.mp3
# Get 11 = oboe_A4_1_mezzo-forte_normal.mp3
# Get 12 = oboe_A4_1_piano_normal.mp3
# Get 13 = oboe_A5_025_forte_normal.mp3
# Get 14 = oboe_A5_025_fortissimo_normal.mp3
# Get 15 = oboe_A5_025_mezzo-forte_normal.mp3
# Get 16 = oboe_A5_025_piano_normal.mp3
# Get 17 = oboe_A5_05_forte_normal.mp3
# Get 18 = oboe_A5_05_fortissimo_normal.mp3
# Get 19 = oboe_A5_05_mezzo-forte_normal.mp3
# Get 20 = oboe_A5_05_piano_normal.mp3
# Get 21 = oboe_A5_15_forte_normal.mp3
# Get 22 = oboe_A5_15_fortissimo_normal.mp3
# Get 23 = oboe_A5_15_mezzo-forte_normal.mp3
# Get 24 = oboe_A5_15_piano_normal.mp3
# Get 25 = oboe_A5_1_forte_major-trill.mp3
# Get 26 = oboe_A5_1_forte_minor-trill.mp3
# Get 27 = oboe_A5_1_forte_normal.mp3
# Get 28 = oboe_A5_1_fortissimo_normal.mp3
# Get 29 = oboe_A5_1_mezzo-forte_normal.mp3
# Get 30 = oboe_A5_1_piano_normal.mp3
# Get 31 = oboe_A6_025_piano_normal.mp3
# Get 32 = oboe_A6_05_piano_normal.mp3
# Get 33 = oboe_A6_15_piano_normal.mp3
# Get 34 = oboe_A6_1_forte_major-trill.mp3
# Get 35 = oboe_A6_1_forte_minor-trill.mp3
# Get 36 = oboe_A6_1_piano_normal.mp3
# Get 37 = oboe_As3_05_forte_normal.mp3
# Get 38 = oboe_As3_05_fortissimo_normal.mp3
# Get 39 = oboe_As3_05_mezzo-forte_normal.mp3
# Get 40 = oboe_As3_05_piano_normal.mp3
# Get 41 = oboe_As3_15_forte_normal.mp3
# Get 42 = oboe_As3_15_fortissimo_normal.mp3
# Get 43 = oboe_As3_15_mezzo-forte_normal.mp3
# Get 44 = oboe_As3_1_forte_normal.mp3
# Get 45 = oboe_As3_1_fortissimo_normal.mp3
# Get 46 = oboe_As3_1_mezzo-forte_normal.mp3
# Get 47 = oboe_As3_1_piano_normal.mp3
# Get 48 = oboe_Ds6_05_fortissimo_normal.mp3
# Get 49 = oboe_Ds6_05_mezzo-forte_normal.mp3
# Get 50 = oboe_Ds6_05_piano_normal.mp3
# Get 51 = oboe_Ds6_15_forte_normal.mp3
# Get 52 = oboe_G6_025_forte_normal.mp3
# Get 53 = oboe_G6_025_mezzo-forte_normal.mp3
# Get 54 = oboe_G6_025_piano_normal.mp3
# Get 55 = oboe_Gs4_025_forte_normal.mp3
# Get 56 = oboe_Gs4_025_fortissimo_normal.mp3
# Get 57 = oboe_Gs4_025_mezzo-forte_normal.mp3
# Get 58 = oboe_Gs4_025_piano_normal.mp3
# Get 59 = oboe_Gs4_05_forte_normal.mp3
# Get 60 = oboe_Gs4_05_fortissimo_normal.mp3
# Get 61 = oboe_Gs4_05_mezzo-forte_normal.mp3
# Get 62 = oboe_Gs4_05_piano_normal.mp3
# Get 63 = oboe_Gs4_15_forte_normal.mp3
# Get 64 = oboe_Gs4_15_fortissimo_normal.mp3
# Get 65 = oboe_Gs4_15_mezzo-forte_normal.mp3
# Get 66 = oboe_Gs4_15_piano_normal.mp3
# Get 67 = oboe_Gs4_1_forte_major-trill.mp3
# Get 68 = oboe_Gs4_1_forte_minor-trill.mp3
# Get 69 = oboe_Gs4_1_forte_normal.mp3
# Get 70 = oboe_Gs4_1_fortissimo_normal.mp3
# Get 71 = oboe_Gs4_1_mezzo-forte_normal.mp3
# Get 72 = oboe_Gs4_1_piano_normal.mp3
# Get 73 = oboe_Gs5_025_forte_normal.mp3
# Get 74 = oboe_Gs5_025_fortissimo_normal.mp3
# Get 75 = oboe_Gs5_025_mezzo-forte_normal.mp3
# Get 76 = oboe_Gs5_025_piano_normal.mp3
# Get 77 = oboe_Gs5_05_forte_normal.mp3
# Get 78 = oboe_Gs5_05_fortissimo_normal.mp3
# Get 79 = oboe_Gs5_05_mezzo-forte_normal.mp3
# Get 80 = oboe_Gs5_05_piano_normal.mp3
# Get 81 = oboe_Gs5_15_forte_normal.mp3
# Get 82 = oboe_Gs5_15_fortissimo_normal.mp3
# Get 83 = oboe_Gs5_15_mezzo-forte_normal.mp3
# Get 84 = oboe_Gs5_15_piano_normal.mp3
# Get 85 = oboe_Gs5_1_forte_normal.mp3
# Get 86 = oboe_Gs5_1_fortissimo_normal.mp3
# Get 87 = oboe_Gs5_1_mezzo-forte_normal.mp3
# Get 88 = oboe_Gs5_1_piano_normal.mp3
# Get 89 = oboe_Gs6_025_forte_normal.mp3
# Get 90 = oboe_Gs6_025_mezzo-forte_normal.mp3
# Get 91 = oboe_Gs6_025_piano_normal.mp3
# Get 92 = oboe_Gs6_05_forte_normal.mp3
# Get 93 = oboe_Gs6_05_mezzo-forte_normal.mp3
# Get 94 = oboe_Gs6_05_piano_normal.mp3
# Get 95 = oboe_Gs6_15_forte_normal.mp3
# Get 96 = oboe_Gs6_15_mezzo-forte_normal.mp3
# Get 97 = oboe_Gs6_15_piano_normal.mp3
# Get 98 = oboe_Gs6_1_forte_normal.mp3
# Get 99 = oboe_Gs6_1_mezzo-forte_normal.mp3
# Get 100 = oboe_Gs6_1_piano_normal.mp3
# Get 1 = saxophone_A3_025_forte_normal.mp3
# Get 2 = saxophone_A3_025_fortissimo_normal.mp3
# Get 3 = saxophone_A3_025_mezzo-piano_normal.mp3
# Get 4 = saxophone_A3_025_pianissimo_normal.mp3
# Get 5 = saxophone_A3_05_forte_normal.mp3
# Get 6 = saxophone_A3_05_fortissimo_normal.mp3
# Get 7 = saxophone_A3_05_mezzo-piano_normal.mp3
# Get 8 = saxophone_A3_05_pianissimo_normal.mp3
# Get 9 = saxophone_A3_05_piano_normal.mp3
# Get 10 = saxophone_A3_15_forte_normal.mp3
# Get 11 = saxophone_A3_15_fortissimo_normal.mp3
# Get 12 = saxophone_A3_15_pianissimo_normal.mp3
# Get 13 = saxophone_A3_1_forte_normal.mp3
# Get 14 = saxophone_A3_1_fortissimo_normal.mp3
# Get 15 = saxophone_A3_1_pianissimo_normal.mp3
# Get 16 = saxophone_A3_1_piano_normal.mp3
# Get 17 = saxophone_A4_025_forte_normal.mp3
# Get 18 = saxophone_A4_025_fortissimo_normal.mp3
# Get 19 = saxophone_A4_025_piano_normal.mp3
# Get 20 = saxophone_A4_05_forte_normal.mp3
# Get 21 = saxophone_A4_05_fortissimo_normal.mp3
# Get 22 = saxophone_A4_05_pianissimo_normal.mp3
# Get 23 = saxophone_A4_05_piano_normal.mp3
# Get 24 = saxophone_A4_15_forte_normal.mp3
# Get 25 = saxophone_A4_15_fortissimo_normal.mp3
# Get 26 = saxophone_A4_15_piano_normal.mp3
# Get 27 = saxophone_A4_1_forte_normal.mp3
# Get 28 = saxophone_A4_1_fortissimo_normal.mp3
# Get 29 = saxophone_A4_1_mezzo-forte_normal.mp3
# Get 30 = saxophone_A4_1_pianissimo_normal.mp3
# Get 31 = saxophone_A4_1_piano_normal.mp3
# Get 32 = saxophone_A5_05_forte_normal.mp3
# Get 33 = saxophone_A5_05_fortissimo_normal.mp3
# Get 34 = saxophone_A5_05_pianissimo_normal.mp3
# Get 35 = saxophone_A5_05_piano_normal.mp3
# Get 36 = saxophone_A5_15_forte_normal.mp3
# Get 37 = saxophone_A5_15_fortissimo_normal.mp3
# Get 38 = saxophone_A5_15_pianissimo_normal.mp3
# Get 39 = saxophone_A5_1_forte_normal.mp3
# Get 40 = saxophone_A5_1_fortissimo_normal.mp3
# Get 41 = saxophone_A5_1_pianissimo_normal.mp3
# Get 42 = saxophone_A5_1_piano_normal.mp3
# Get 43 = saxophone_Ds4_025_forte_normal.mp3
# Get 44 = saxophone_Ds4_025_fortissimo_normal.mp3
# Get 45 = saxophone_Ds4_025_mezzo-forte_normal.mp3
# Get 46 = saxophone_Ds4_025_pianissimo_normal.mp3
# Get 47 = saxophone_Ds4_05_fortissimo_normal.mp3
# Get 48 = saxophone_Ds4_05_mezzo-forte_normal.mp3
# Get 49 = saxophone_Ds4_05_mezzo-forte_slap-tongue.mp3
# Get 50 = saxophone_Ds4_05_pianissimo_normal.mp3
# Get 51 = saxophone_Ds4_05_pianissimo_subtone.mp3
# Get 52 = saxophone_Ds4_05_piano_normal.mp3
# Get 53 = saxophone_Ds4_15_fortissimo_normal.mp3
# Get 54 = saxophone_Ds5_1_forte_major-trill.mp3
# Get 55 = saxophone_Ds5_1_forte_minor-trill.mp3
# Get 56 = saxophone_Gs3_025_forte_normal.mp3
# Get 57 = saxophone_Gs3_025_fortissimo_normal.mp3
# Get 58 = saxophone_Gs3_025_mezzo-piano_normal.mp3
# Get 59 = saxophone_Gs3_05_forte_normal.mp3
# Get 60 = saxophone_Gs3_05_fortissimo_normal.mp3
# Get 61 = saxophone_Gs3_05_mezzo-piano_normal.mp3
# Get 62 = saxophone_Gs3_05_pianissimo_normal.mp3
# Get 63 = saxophone_Gs3_05_piano_normal.mp3
# Get 64 = saxophone_Gs3_15_fortissimo_normal.mp3
# Get 65 = saxophone_Gs3_15_pianissimo_normal.mp3
# Get 66 = saxophone_Gs3_1_pianissimo_normal.mp3
# Get 67 = saxophone_Gs3_1_piano_normal.mp3
# Get 68 = saxophone_Gs4_025_forte_normal.mp3
# Get 69 = saxophone_Gs4_025_fortissimo_normal.mp3
# Get 70 = saxophone_Gs4_025_mezzo-forte_normal.mp3
# Get 71 = saxophone_Gs4_025_pianissimo_normal.mp3
# Get 72 = saxophone_Gs4_025_piano_normal.mp3
# Get 73 = saxophone_Gs4_05_forte_normal.mp3
# Get 74 = saxophone_Gs4_05_fortissimo_normal.mp3
# Get 75 = saxophone_Gs4_05_mezzo-forte_normal.mp3
# Get 76 = saxophone_Gs4_05_pianissimo_normal.mp3
# Get 77 = saxophone_Gs4_05_piano_normal.mp3
# Get 78 = saxophone_Gs4_15_forte_normal.mp3
# Get 79 = saxophone_Gs4_15_fortissimo_normal.mp3
# Get 80 = saxophone_Gs4_15_pianissimo_normal.mp3
# Get 81 = saxophone_Gs4_15_piano_normal.mp3
# Get 82 = saxophone_Gs4_1_forte_normal.mp3
# Get 83 = saxophone_Gs4_1_fortissimo_normal.mp3
# Get 84 = saxophone_Gs4_1_pianissimo_normal.mp3
# Get 85 = saxophone_Gs4_1_piano_normal.mp3
# Get 86 = saxophone_Gs5_025_forte_normal.mp3
# Get 87 = saxophone_Gs5_025_fortissimo_normal.mp3
# Get 88 = saxophone_Gs5_025_piano_normal.mp3
# Get 89 = saxophone_Gs5_05_forte_normal.mp3
# Get 90 = saxophone_Gs5_05_fortissimo_normal.mp3
# Get 91 = saxophone_Gs5_05_pianissimo_normal.mp3
# Get 92 = saxophone_Gs5_05_piano_normal.mp3
# Get 93 = saxophone_Gs5_15_forte_normal.mp3
# Get 94 = saxophone_Gs5_15_fortissimo_normal.mp3
# Get 95 = saxophone_Gs5_15_pianissimo_normal.mp3
# Get 96 = saxophone_Gs5_15_piano_normal.mp3
# Get 97 = saxophone_Gs5_1_forte_normal.mp3
# Get 98 = saxophone_Gs5_1_fortissimo_normal.mp3
# Get 99 = saxophone_Gs5_1_pianissimo_normal.mp3
# Get 100 = saxophone_Gs5_1_piano_normal.mp3
# Get 1 = trumpet_A3_025_pianissimo_normal.mp3
# Get 2 = trumpet_A3_05_forte_normal.mp3
# Get 3 = trumpet_A3_05_pianissimo_normal.mp3
# Get 4 = trumpet_A3_15_pianissimo_normal.mp3
# Get 5 = trumpet_A3_1_pianissimo_normal.mp3
# Get 6 = trumpet_A4_025_forte_normal.mp3
# Get 7 = trumpet_A4_05_forte_normal.mp3
# Get 8 = trumpet_A5_025_forte_normal.mp3
# Get 9 = trumpet_A5_025_mezzo-forte_normal.mp3
# Get 10 = trumpet_A5_05_mezzo-forte_normal.mp3
# Get 11 = trumpet_As3_025_forte_normal.mp3
# Get 12 = trumpet_As3_025_pianissimo_normal.mp3
# Get 13 = trumpet_As3_05_pianissimo_normal.mp3
# Get 14 = trumpet_As3_15_pianissimo_normal.mp3
# Get 15 = trumpet_As3_1_pianissimo_normal.mp3
# Get 16 = trumpet_As4_025_forte_normal.mp3
# Get 17 = trumpet_As5_025_forte_normal.mp3
# Get 18 = trumpet_As5_05_forte_normal.mp3
# Get 19 = trumpet_As5_05_mezzo-forte_normal.mp3
# Get 20 = trumpet_B3_025_forte_normal.mp3
# Get 21 = trumpet_B3_025_pianissimo_normal.mp3
# Get 22 = trumpet_B3_05_forte_normal.mp3
# Get 23 = trumpet_B3_05_pianissimo_normal.mp3
# Get 24 = trumpet_B3_15_pianissimo_normal.mp3
# Get 25 = trumpet_B3_1_pianissimo_normal.mp3
# Get 26 = trumpet_B4_025_forte_normal.mp3
# Get 27 = trumpet_B5_025_forte_normal.mp3
# Get 28 = trumpet_B5_025_mezzo-forte_normal.mp3
# Get 29 = trumpet_C4_025_forte_normal.mp3
# Get 30 = trumpet_C4_025_pianissimo_normal.mp3
# Get 31 = trumpet_C4_05_forte_normal.mp3
# Get 32 = trumpet_C4_05_pianissimo_normal.mp3
# Get 33 = trumpet_C4_15_pianissimo_normal.mp3
# Get 34 = trumpet_C4_1_pianissimo_normal.mp3
# Get 35 = trumpet_C6_025_forte_normal.mp3
# Get 88 = trumpet_G5_1_mezzo-forte_normal.mp3
# Get 89 = trumpet_Gs3_025_pianissimo_normal.mp3
# Get 90 = trumpet_Gs3_05_forte_normal.mp3
# Get 91 = trumpet_Gs3_05_pianissimo_normal.mp3
# Get 92 = trumpet_Gs3_15_pianissimo_normal.mp3
# Get 93 = trumpet_Gs3_1_forte_normal.mp3
# Get 94 = trumpet_Gs3_1_pianissimo_normal.mp3
# Get 95 = trumpet_Gs4_025_forte_normal.mp3
# Get 96 = trumpet_Gs4_05_forte_normal.mp3
# Get 97 = trumpet_Gs5_025_forte_normal.mp3
# Get 98 = trumpet_Gs5_025_mezzo-forte_normal.mp3
# Get 99 = trumpet_Gs5_05_forte_normal.mp3
# Get 100 = trumpet_Gs5_05_mezzo-forte_normal.mp3
# Get 1 = viola_A3_025_fortissimo_arco-normal.mp3
# Get 2 = viola_A3_025_mezzo-piano_arco-normal.mp3
# Get 3 = viola_A3_025_pianissimo_arco-normal.mp3
# Get 4 = viola_A3_025_piano_arco-normal.mp3
# Get 5 = viola_A3_05_fortissimo_arco-normal.mp3
# Get 6 = viola_A3_05_mezzo-piano_arco-normal.mp3
# Get 7 = viola_A3_05_pianissimo_arco-normal.mp3
# Get 8 = viola_A3_05_piano_arco-normal.mp3
# Get 9 = viola_A3_15_forte_arco-normal.mp3
# Get 10 = viola_A3_15_fortissimo_arco-normal.mp3
# Get 11 = viola_A3_15_piano_arco-normal.mp3
# Get 12 = viola_A3_1_forte_arco-normal.mp3
# Get 13 = viola_A3_1_fortissimo_arco-normal.mp3
# Get 14 = viola_A3_1_fortissimo_pizz-normal.mp3
# Get 15 = viola_A3_1_mezzo-forte_molto-vibrato.mp3
# Get 16 = viola_A3_1_mezzo-piano_non-vibrato.mp3
# Get 17 = viola_A3_1_pianissimo_arco-normal.mp3
# Get 18 = viola_A3_1_piano_arco-glissando.mp3
# Get 19 = viola_A3_1_piano_arco-normal.mp3
# Get 20 = viola_A3_1_piano_pizz-normal.mp3
# Get 21 = viola_A4_025_fortissimo_arco-normal.mp3
# Get 22 = viola_A4_025_mezzo-piano_arco-normal.mp3
# Get 23 = viola_A4_025_pianissimo_arco-normal.mp3
# Get 24 = viola_A4_025_piano_arco-normal.mp3
# Get 25 = viola_A4_05_forte_arco-normal.mp3
# Get 26 = viola_A4_05_fortissimo_arco-normal.mp3
# Get 27 = viola_A4_05_mezzo-piano_arco-normal.mp3
# Get 28 = viola_A4_05_pianissimo_arco-normal.mp3
# Get 29 = viola_A4_05_piano_arco-normal.mp3
# Get 30 = viola_A4_15_fortissimo_arco-normal.mp3
# Get 31 = viola_A4_15_pianissimo_arco-normal.mp3
# Get 32 = viola_A4_15_piano_arco-normal.mp3
# Get 33 = viola_A4_1_forte_arco-normal.mp3
# Get 34 = viola_A4_1_fortissimo_arco-normal.mp3
# Get 35 = viola_A4_1_fortissimo_snap-pizz.mp3
# Get 36 = viola_A4_1_mezzo-forte_arco-major-trill.mp3
# Get 37 = viola_A4_1_mezzo-forte_arco-minor-trill.mp3
# Get 38 = viola_A4_1_mezzo-forte_molto-vibrato.mp3
# Get 39 = viola_A4_1_mezzo-piano_non-vibrato.mp3
# Get 40 = viola_A4_1_pianissimo_arco-normal.mp3
# Get 41 = viola_A4_1_piano_arco-glissando.mp3
# Get 42 = viola_A4_1_piano_arco-normal.mp3
# Get 43 = viola_A4_1_piano_pizz-normal.mp3
# Get 44 = viola_A5_1_forte_arco-normal.mp3
# Get 45 = viola_A5_1_fortissimo_arco-normal.mp3
# Get 46 = viola_A5_1_mezzo-forte_artificial-harmonic.mp3
# Get 47 = viola_A5_1_pianissimo_arco-normal.mp3
# Get 48 = viola_Ds3_05_fortissimo_arco-normal.mp3
# Get 49 = viola_Ds3_05_mezzo-piano_arco-normal.mp3
# Get 50 = viola_Ds3_1_piano_pizz-normal.mp3
# Get 51 = viola_Gs3_025_fortissimo_arco-normal.mp3
# Get 52 = viola_Gs3_025_mezzo-piano_arco-normal.mp3
# Get 53 = viola_Gs3_025_pianissimo_arco-normal.mp3
# Get 54 = viola_Gs3_025_piano_arco-normal.mp3
# Get 55 = viola_Gs3_15_fortissimo_arco-normal.mp3
# Get 56 = viola_Gs3_15_pianissimo_arco-normal.mp3
# Get 57 = viola_Gs3_15_piano_arco-normal.mp3
# Get 58 = viola_Gs4_025_fortissimo_arco-normal.mp3
# Get 59 = viola_Gs4_025_mezzo-piano_arco-normal.mp3
# Get 60 = viola_Gs4_025_pianissimo_arco-normal.mp3
# Get 61 = viola_Gs4_05_fortissimo_arco-normal.mp3
# Get 62 = viola_Gs4_05_mezzo-piano_arco-normal.mp3
# Get 63 = viola_Gs4_05_pianissimo_arco-normal.mp3
# Get 64 = viola_Gs4_05_piano_arco-normal.mp3
# Get 65 = viola_Gs4_15_fortissimo_arco-normal.mp3
# Get 66 = viola_Gs4_15_mezzo-piano_arco-normal.mp3
# Get 67 = viola_Gs4_15_pianissimo_arco-normal.mp3
# Get 68 = viola_Gs4_1_fortissimo_arco-normal.mp3
# Get 69 = viola_Gs4_1_mezzo-piano_arco-normal.mp3
# Get 70 = viola_Gs4_1_pianissimo_arco-normal.mp3
# Get 71 = viola_Gs4_1_piano_arco-normal.mp3
# Get 72 = viola_Gs5_025_forte_arco-normal.mp3
# Get 73 = viola_Gs5_025_fortissimo_arco-normal.mp3
# Get 74 = viola_Gs5_025_mezzo-piano_arco-normal.mp3
# Get 75 = viola_Gs5_025_pianissimo_arco-normal.mp3
# Get 76 = viola_Gs5_05_forte_arco-normal.mp3
# Get 77 = viola_Gs5_05_fortissimo_arco-normal.mp3
# Get 78 = viola_Gs5_05_pianissimo_arco-normal.mp3
# Get 79 = viola_Gs5_05_piano_arco-normal.mp3
# Get 80 = viola_Gs5_15_fortissimo_arco-normal.mp3
# Get 81 = viola_Gs5_15_pianissimo_arco-normal.mp3
# Get 82 = viola_Gs5_1_forte_arco-normal.mp3
# Get 83 = viola_Gs5_1_fortissimo_arco-normal.mp3
# Get 84 = viola_Gs5_1_fortissimo_snap-pizz.mp3
# Get 85 = viola_Gs5_1_pianissimo_arco-normal.mp3
# Get 86 = viola_Gs5_1_piano_arco-normal.mp3
# Get 87 = viola_Gs6_025_forte_arco-normal.mp3
# Get 88 = viola_Gs6_025_fortissimo_arco-normal.mp3
# Get 89 = viola_Gs6_025_mezzo-piano_arco-normal.mp3
# Get 90 = viola_Gs6_025_pianissimo_arco-normal.mp3
# Get 91 = viola_Gs6_025_piano_arco-normal.mp3
# Get 92 = viola_Gs6_05_forte_arco-normal.mp3
# Get 93 = viola_Gs6_05_fortissimo_arco-normal.mp3
# Get 94 = viola_Gs6_05_pianissimo_arco-normal.mp3
# Get 95 = viola_Gs6_05_piano_arco-normal.mp3
# Get 96 = viola_Gs6_15_forte_arco-normal.mp3
# Get 97 = viola_Gs6_15_fortissimo_arco-normal.mp3
# Get 98 = viola_Gs6_1_forte_arco-normal.mp3
# Get 99 = viola_Gs6_1_fortissimo_arco-normal.mp3
# Get 100 = viola_Gs6_1_pianissimo_arco-normal.mp3
# Found 780 audio files in ./audio/

# %%
print("Max. Duration:", max(duration))
print("Min. Duration:", min(duration))
print("Average Duration:", np.mean(duration))
# Out:
# Max. Duration: 27.704308390022675
# Min. Duration: 0.22058956916099773
# Average Duration: 1.5068857491714636

# %% [markdown]
# #### This code iterates over the list of audio file paths (`files`). For each file, it loads the audio data using librosa, trims any silent sections using a threshold of 60 decibels, and calculates the duration of the trimmed audio. If an error occurs during loading or processing, it prints an error message. Finally, it prints the total number of durations calculated.

# %%
# Load audio files, trim silence and calculate duration
duration = []
for i,f in enumerate(files):
    print ("Get %d  %s"%(i+1, f))
    try:
        y, sr = librosa.load(f, sr=fs)
        if len(y) < 2:
            print("Error loading %s" % f)
            continue
        #y/=y.max() #Normalize
        yt, index = librosa.effects.trim(y,top_db=60) #Trim
        duration.append(librosa.get_duration(y = yt, sr=fs))
    except Exception as e:
        print("Error loading %s. Error: %s" % (f,e))
        
print("Calculated %d Durations"%len(duration))
# Out:
# Get 1  ./audio/cello\cello_A2_025_forte_arco-normal.mp3
# Get 2  ./audio/cello\cello_A2_025_fortissimo_arco-normal.mp3
# Get 3  ./audio/cello\cello_A2_025_mezzo-forte_arco-col-legno-battuto.mp3
# Get 4  ./audio/cello\cello_A2_025_mezzo-piano_arco-normal.mp3
# Get 5  ./audio/cello\cello_A2_025_pianissimo_arco-normal.mp3
# Get 6  ./audio/cello\cello_A2_05_forte_arco-normal.mp3
# Get 7  ./audio/cello\cello_A2_05_fortissimo_arco-normal.mp3
# Get 8  ./audio/cello\cello_A2_05_mezzo-piano_arco-normal.mp3
# Get 9  ./audio/cello\cello_A2_05_pianissimo_arco-normal.mp3
# Get 10  ./audio/cello\cello_A2_15_forte_arco-normal.mp3
# Get 11  ./audio/cello\cello_A2_15_pianissimo_arco-normal.mp3
# Get 12  ./audio/cello\cello_A2_15_piano_arco-normal.mp3
# Get 13  ./audio/cello\cello_A2_1_forte_arco-normal.mp3
# Get 14  ./audio/cello\cello_A2_1_fortissimo_arco-normal.mp3
# Get 131  ./audio/contrabassoon\contrabassoon_A3_05_forte_normal.mp3
# Get 132  ./audio/contrabassoon\contrabassoon_A3_05_fortissimo_normal.mp3
# Get 133  ./audio/contrabassoon\contrabassoon_A3_05_mezzo-forte_normal.mp3
# Get 134  ./audio/contrabassoon\contrabassoon_A3_05_piano_normal.mp3
# Get 135  ./audio/contrabassoon\contrabassoon_A3_15_forte_normal.mp3
# Get 136  ./audio/contrabassoon\contrabassoon_A3_15_fortissimo_normal.mp3
# Get 137  ./audio/contrabassoon\contrabassoon_A3_15_mezzo-forte_normal.mp3
# Get 138  ./audio/contrabassoon\contrabassoon_A3_15_piano_normal.mp3
# Get 139  ./audio/contrabassoon\contrabassoon_A3_1_forte_normal.mp3
# Get 140  ./audio/contrabassoon\contrabassoon_A3_1_fortissimo_normal.mp3
# Get 141  ./audio/contrabassoon\contrabassoon_A3_1_mezzo-forte_normal.mp3
# Get 142  ./audio/contrabassoon\contrabassoon_A3_1_piano_normal.mp3
# Get 143  ./audio/contrabassoon\contrabassoon_A3_very-long_forte_normal.mp3
# Get 144  ./audio/contrabassoon\contrabassoon_A3_very-long_piano_normal.mp3
# Get 145  ./audio/contrabassoon\contrabassoon_As0_025_forte_normal.mp3
# Get 146  ./audio/contrabassoon\contrabassoon_As0_025_mezzo-forte_normal.mp3
# Get 147  ./audio/contrabassoon\contrabassoon_As0_05_forte_normal.mp3
# Get 148  ./audio/contrabassoon\contrabassoon_As0_05_mezzo-forte_normal.mp3
# Get 149  ./audio/contrabassoon\contrabassoon_As0_15_forte_normal.mp3
# Get 150  ./audio/contrabassoon\contrabassoon_As0_15_fortissimo_normal.mp3
# Get 151  ./audio/contrabassoon\contrabassoon_As0_15_mezzo-forte_normal.mp3
# Get 152  ./audio/contrabassoon\contrabassoon_As0_1_forte_normal.mp3
# Get 153  ./audio/contrabassoon\contrabassoon_As0_1_fortissimo_normal.mp3
# Get 154  ./audio/contrabassoon\contrabassoon_As0_1_mezzo-forte_normal.mp3
# Get 155  ./audio/contrabassoon\contrabassoon_As0_long_forte_major-trill.mp3
# Get 156  ./audio/contrabassoon\contrabassoon_As0_long_forte_tremolo.mp3
# Get 157  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_legato.mp3
# Get 158  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_nonlegato.mp3
# Get 159  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_staccatissimo.mp3
# Get 160  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_staccato.mp3
# Get 161  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_tenuto.mp3
# Get 162  ./audio/contrabassoon\contrabassoon_As0_phrase_mezzo-forte_tongued-slur.mp3
# Get 163  ./audio/contrabassoon\contrabassoon_As0_very-long_cresc-decresc_normal.mp3
# Get 164  ./audio/contrabassoon\contrabassoon_As1_025_forte_normal.mp3
# Get 165  ./audio/contrabassoon\contrabassoon_As1_025_fortissimo_normal.mp3
# Get 166  ./audio/contrabassoon\contrabassoon_As1_025_mezzo-forte_normal.mp3
# Get 167  ./audio/contrabassoon\contrabassoon_As1_025_piano_normal.mp3
# Get 168  ./audio/contrabassoon\contrabassoon_As1_05_forte_normal.mp3
# Get 169  ./audio/contrabassoon\contrabassoon_As1_05_fortissimo_normal.mp3
# Get 170  ./audio/contrabassoon\contrabassoon_As1_05_mezzo-forte_normal.mp3
# Get 171  ./audio/contrabassoon\contrabassoon_As1_05_piano_normal.mp3
# Get 172  ./audio/contrabassoon\contrabassoon_As1_15_forte_normal.mp3
# Get 173  ./audio/contrabassoon\contrabassoon_As1_15_fortissimo_normal.mp3
# Get 174  ./audio/contrabassoon\contrabassoon_As1_15_mezzo-forte_normal.mp3
# Get 175  ./audio/contrabassoon\contrabassoon_As1_15_piano_normal.mp3
# Get 176  ./audio/contrabassoon\contrabassoon_As1_1_forte_normal.mp3
# Get 177  ./audio/contrabassoon\contrabassoon_As1_1_fortissimo_normal.mp3
# Get 178  ./audio/contrabassoon\contrabassoon_As1_1_mezzo-forte_normal.mp3
# Get 179  ./audio/contrabassoon\contrabassoon_As1_1_piano_normal.mp3
# Get 180  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_legato.mp3
# Get 181  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_nonlegato.mp3
# Get 182  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_staccatissimo.mp3
# Get 183  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_staccato.mp3
# Get 184  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_tenuto.mp3
# Get 185  ./audio/contrabassoon\contrabassoon_As1_phrase_mezzo-forte_tongued-slur.mp3
# Get 186  ./audio/contrabassoon\contrabassoon_As1_very-long_cresc-decresc_normal.mp3
# Get 187  ./audio/contrabassoon\contrabassoon_As2_025_forte_normal.mp3
# Get 188  ./audio/contrabassoon\contrabassoon_As2_05_forte_normal.mp3
# Get 189  ./audio/contrabassoon\contrabassoon_As2_05_fortissimo_normal.mp3
# Get 190  ./audio/contrabassoon\contrabassoon_As2_05_mezzo-forte_normal.mp3
# Get 191  ./audio/contrabassoon\contrabassoon_As2_05_piano_normal.mp3
# Get 192  ./audio/contrabassoon\contrabassoon_As2_15_forte_normal.mp3
# Get 193  ./audio/contrabassoon\contrabassoon_As2_15_fortissimo_normal.mp3
# Get 194  ./audio/contrabassoon\contrabassoon_As2_15_mezzo-forte_normal.mp3
# Get 195  ./audio/contrabassoon\contrabassoon_As2_15_piano_normal.mp3
# Get 196  ./audio/contrabassoon\contrabassoon_As2_1_forte_fluttertonguing.mp3
# Get 197  ./audio/contrabassoon\contrabassoon_As2_1_forte_normal.mp3
# Get 198  ./audio/contrabassoon\contrabassoon_As2_1_fortissimo_normal.mp3
# Get 199  ./audio/contrabassoon\contrabassoon_As2_1_mezzo-forte_normal.mp3
# Get 200  ./audio/contrabassoon\contrabassoon_As2_1_piano_normal.mp3
# Get 201  ./audio/flute\flute_A4_025_forte_normal.mp3
# Get 202  ./audio/flute\flute_A4_025_mezzo-forte_normal.mp3
# Get 203  ./audio/flute\flute_A4_025_mezzo-piano_normal.mp3
# Get 204  ./audio/flute\flute_A4_025_pianissimo_normal.mp3
# Get 205  ./audio/flute\flute_A4_025_piano_normal.mp3
# Get 206  ./audio/flute\flute_A4_05_forte_normal.mp3
# Get 207  ./audio/flute\flute_A4_05_mezzo-forte_normal.mp3
# Get 208  ./audio/flute\flute_A4_05_mezzo-piano_normal.mp3
# Get 209  ./audio/flute\flute_A4_05_pianissimo_normal.mp3
# Get 296  ./audio/flute\flute_Gs6_15_piano_normal.mp3
# Get 297  ./audio/flute\flute_Gs6_1_forte_normal.mp3
# Get 298  ./audio/flute\flute_Gs6_1_mezzo-forte_normal.mp3
# Get 299  ./audio/flute\flute_Gs6_1_pianissimo_normal.mp3
# Get 300  ./audio/flute\flute_Gs6_1_piano_normal.mp3
# Get 301  ./audio/mandolin\mandolin_A3_very-long_forte_tremolo.mp3
# Get 302  ./audio/mandolin\mandolin_A3_very-long_piano_normal.mp3
# Get 303  ./audio/mandolin\mandolin_A4_very-long_forte_tremolo.mp3
# Get 304  ./audio/mandolin\mandolin_A4_very-long_piano_normal.mp3
# Get 305  ./audio/mandolin\mandolin_A4_very-long_piano_tremolo.mp3
# Get 306  ./audio/mandolin\mandolin_A5_very-long_forte_tremolo.mp3
# Get 307  ./audio/mandolin\mandolin_A5_very-long_piano_normal.mp3
# Get 308  ./audio/mandolin\mandolin_A6_very-long_piano_normal.mp3
# Get 309  ./audio/mandolin\mandolin_A6_very-long_piano_tremolo.mp3
# Get 310  ./audio/mandolin\mandolin_As3_very-long_forte_tremolo.mp3
# Get 311  ./audio/mandolin\mandolin_As3_very-long_piano_normal.mp3
# Get 312  ./audio/mandolin\mandolin_As4_very-long_piano_normal.mp3
# Get 313  ./audio/mandolin\mandolin_As4_very-long_piano_tremolo.mp3
# Get 314  ./audio/mandolin\mandolin_As5_very-long_piano_normal.mp3
# Get 315  ./audio/mandolin\mandolin_As5_very-long_piano_tremolo.mp3
# Get 316  ./audio/mandolin\mandolin_B3_very-long_piano_normal.mp3
# Get 317  ./audio/mandolin\mandolin_B3_very-long_piano_tremolo.mp3
# Get 318  ./audio/mandolin\mandolin_B4_very-long_piano_normal.mp3
# Get 319  ./audio/mandolin\mandolin_B4_very-long_piano_tremolo.mp3
# Get 320  ./audio/mandolin\mandolin_B5_very-long_piano_normal.mp3
# Get 321  ./audio/mandolin\mandolin_B5_very-long_piano_tremolo.mp3
# Get 322  ./audio/mandolin\mandolin_C4_very-long_piano_normal.mp3
# Get 323  ./audio/mandolin\mandolin_C4_very-long_piano_tremolo.mp3
# Get 324  ./audio/mandolin\mandolin_C5_very-long_piano_normal.mp3
# Get 325  ./audio/mandolin\mandolin_C5_very-long_piano_tremolo.mp3
# Get 326  ./audio/mandolin\mandolin_C6_very-long_piano_normal.mp3
# Get 327  ./audio/mandolin\mandolin_C6_very-long_piano_tremolo.mp3
# Get 328  ./audio/mandolin\mandolin_Cs4_very-long_piano_normal.mp3
# Get 329  ./audio/mandolin\mandolin_Cs4_very-long_piano_tremolo.mp3
# Get 330  ./audio/mandolin\mandolin_Cs5_very-long_piano_normal.mp3
# Get 331  ./audio/mandolin\mandolin_Cs5_very-long_piano_tremolo.mp3
# Get 332  ./audio/mandolin\mandolin_Cs6_very-long_piano_normal.mp3
# Get 333  ./audio/mandolin\mandolin_Cs6_very-long_piano_tremolo.mp3
# Get 334  ./audio/mandolin\mandolin_D4_very-long_piano_normal.mp3
# Get 335  ./audio/mandolin\mandolin_D4_very-long_piano_tremolo.mp3
# Get 336  ./audio/mandolin\mandolin_D5_very-long_forte_tremolo.mp3
# Get 337  ./audio/mandolin\mandolin_D5_very-long_piano_normal.mp3
# Get 338  ./audio/mandolin\mandolin_D6_very-long_piano_normal.mp3
# Get 339  ./audio/mandolin\mandolin_D6_very-long_piano_tremolo.mp3
# Get 340  ./audio/mandolin\mandolin_Ds4_very-long_piano_normal.mp3
# Get 341  ./audio/mandolin\mandolin_Ds4_very-long_piano_tremolo.mp3
# Get 342  ./audio/mandolin\mandolin_Ds5_very-long_piano_normal.mp3
# Get 343  ./audio/mandolin\mandolin_Ds5_very-long_piano_tremolo.mp3
# Get 344  ./audio/mandolin\mandolin_Ds6_very-long_piano_normal.mp3
# Get 345  ./audio/mandolin\mandolin_Ds6_very-long_piano_tremolo.mp3
# Get 346  ./audio/mandolin\mandolin_E4_very-long_piano_normal.mp3
# Get 347  ./audio/mandolin\mandolin_E4_very-long_piano_tremolo.mp3
# Get 348  ./audio/mandolin\mandolin_E5_very-long_piano_normal.mp3
# Get 349  ./audio/mandolin\mandolin_E5_very-long_piano_tremolo.mp3
# Get 350  ./audio/mandolin\mandolin_E6_very-long_piano_normal.mp3
# Get 351  ./audio/mandolin\mandolin_E6_very-long_piano_tremolo.mp3
# Get 352  ./audio/mandolin\mandolin_F4_very-long_piano_normal.mp3
# Get 353  ./audio/mandolin\mandolin_F4_very-long_piano_tremolo.mp3
# Get 354  ./audio/mandolin\mandolin_F5_very-long_piano_normal.mp3
# Get 355  ./audio/mandolin\mandolin_F5_very-long_piano_tremolo.mp3
# Get 356  ./audio/mandolin\mandolin_F6_very-long_piano_normal.mp3
# Get 357  ./audio/mandolin\mandolin_F6_very-long_piano_tremolo.mp3
# Get 358  ./audio/mandolin\mandolin_Fs4_very-long_piano_normal.mp3
# Get 359  ./audio/mandolin\mandolin_Fs4_very-long_piano_tremolo.mp3
# Get 360  ./audio/mandolin\mandolin_Fs5_very-long_piano_normal.mp3
# Get 361  ./audio/mandolin\mandolin_Fs5_very-long_piano_tremolo.mp3
# Get 362  ./audio/mandolin\mandolin_Fs6_very-long_piano_normal.mp3
# Get 363  ./audio/mandolin\mandolin_Fs6_very-long_piano_tremolo.mp3
# Get 364  ./audio/mandolin\mandolin_G3_very-long_forte_tremolo.mp3
# Get 365  ./audio/mandolin\mandolin_G3_very-long_piano_normal.mp3
# Get 366  ./audio/mandolin\mandolin_G3_very-long_piano_tremolo.mp3
# Get 367  ./audio/mandolin\mandolin_G4_very-long_forte_tremolo.mp3
# Get 368  ./audio/mandolin\mandolin_G4_very-long_piano_normal.mp3
# Get 369  ./audio/mandolin\mandolin_G5_very-long_piano_normal.mp3
# Get 370  ./audio/mandolin\mandolin_G5_very-long_piano_tremolo.mp3
# Get 371  ./audio/mandolin\mandolin_G6_very-long_piano_normal.mp3
# Get 372  ./audio/mandolin\mandolin_G6_very-long_piano_tremolo.mp3
# Get 373  ./audio/mandolin\mandolin_Gs3_very-long_piano_normal.mp3
# Get 498  ./audio/sax\saxophone_A4_025_fortissimo_normal.mp3
# Get 499  ./audio/sax\saxophone_A4_025_piano_normal.mp3
# Get 500  ./audio/sax\saxophone_A4_05_forte_normal.mp3
# Get 501  ./audio/sax\saxophone_A4_05_fortissimo_normal.mp3
# Get 502  ./audio/sax\saxophone_A4_05_pianissimo_normal.mp3
# Get 503  ./audio/sax\saxophone_A4_05_piano_normal.mp3
# Get 504  ./audio/sax\saxophone_A4_15_forte_normal.mp3
# Get 505  ./audio/sax\saxophone_A4_15_fortissimo_normal.mp3
# Get 506  ./audio/sax\saxophone_A4_15_piano_normal.mp3
# Get 507  ./audio/sax\saxophone_A4_1_forte_normal.mp3
# Get 508  ./audio/sax\saxophone_A4_1_fortissimo_normal.mp3
# Get 509  ./audio/sax\saxophone_A4_1_mezzo-forte_normal.mp3
# Get 510  ./audio/sax\saxophone_A4_1_pianissimo_normal.mp3
# Get 511  ./audio/sax\saxophone_A4_1_piano_normal.mp3
# Get 512  ./audio/sax\saxophone_A5_05_forte_normal.mp3
# Get 513  ./audio/sax\saxophone_A5_05_fortissimo_normal.mp3
# Get 514  ./audio/sax\saxophone_A5_05_pianissimo_normal.mp3
# Get 515  ./audio/sax\saxophone_A5_05_piano_normal.mp3
# Get 516  ./audio/sax\saxophone_A5_15_forte_normal.mp3
# Get 517  ./audio/sax\saxophone_A5_15_fortissimo_normal.mp3
# Get 518  ./audio/sax\saxophone_A5_15_pianissimo_normal.mp3
# Get 519  ./audio/sax\saxophone_A5_1_forte_normal.mp3
# Get 520  ./audio/sax\saxophone_A5_1_fortissimo_normal.mp3
# Get 521  ./audio/sax\saxophone_A5_1_pianissimo_normal.mp3
# Get 522  ./audio/sax\saxophone_A5_1_piano_normal.mp3
# Get 523  ./audio/sax\saxophone_Ds4_025_forte_normal.mp3
# Get 524  ./audio/sax\saxophone_Ds4_025_fortissimo_normal.mp3
# Get 525  ./audio/sax\saxophone_Ds4_025_mezzo-forte_normal.mp3
# Get 526  ./audio/sax\saxophone_Ds4_025_pianissimo_normal.mp3
# Get 527  ./audio/sax\saxophone_Ds4_05_fortissimo_normal.mp3
# Get 528  ./audio/sax\saxophone_Ds4_05_mezzo-forte_normal.mp3
# Get 529  ./audio/sax\saxophone_Ds4_05_mezzo-forte_slap-tongue.mp3
# Get 530  ./audio/sax\saxophone_Ds4_05_pianissimo_normal.mp3
# Get 531  ./audio/sax\saxophone_Ds4_05_pianissimo_subtone.mp3
# Get 532  ./audio/sax\saxophone_Ds4_05_piano_normal.mp3
# Get 533  ./audio/sax\saxophone_Ds4_15_fortissimo_normal.mp3
# Get 534  ./audio/sax\saxophone_Ds5_1_forte_major-trill.mp3
# Get 535  ./audio/sax\saxophone_Ds5_1_forte_minor-trill.mp3
# Get 536  ./audio/sax\saxophone_Gs3_025_forte_normal.mp3
# Get 537  ./audio/sax\saxophone_Gs3_025_fortissimo_normal.mp3
# Get 538  ./audio/sax\saxophone_Gs3_025_mezzo-piano_normal.mp3
# Get 660  ./audio/trumpet\trumpet_F4_05_pianissimo_normal.mp3
# Get 661  ./audio/trumpet\trumpet_G3_025_pianissimo_normal.mp3
# Get 662  ./audio/trumpet\trumpet_G3_05_pianissimo_normal.mp3
# Get 663  ./audio/trumpet\trumpet_G3_15_pianissimo_normal.mp3
# Get 664  ./audio/trumpet\trumpet_G3_1_pianissimo_normal.mp3
# Get 665  ./audio/trumpet\trumpet_G5_025_mezzo-forte_normal.mp3
# Get 666  ./audio/trumpet\trumpet_G5_05_mezzo-forte_normal.mp3
# Get 667  ./audio/trumpet\trumpet_G5_15_mezzo-forte_normal.mp3
# Get 668  ./audio/trumpet\trumpet_G5_1_mezzo-forte_normal.mp3
# Get 669  ./audio/trumpet\trumpet_Gs3_025_pianissimo_normal.mp3
# Get 670  ./audio/trumpet\trumpet_Gs3_05_forte_normal.mp3
# Get 671  ./audio/trumpet\trumpet_Gs3_05_pianissimo_normal.mp3
# Get 672  ./audio/trumpet\trumpet_Gs3_15_pianissimo_normal.mp3
# Get 673  ./audio/trumpet\trumpet_Gs3_1_forte_normal.mp3
# Get 674  ./audio/trumpet\trumpet_Gs3_1_pianissimo_normal.mp3
# Get 675  ./audio/trumpet\trumpet_Gs4_025_forte_normal.mp3
# Get 676  ./audio/trumpet\trumpet_Gs4_05_forte_normal.mp3
# Get 677  ./audio/trumpet\trumpet_Gs5_025_forte_normal.mp3
# Get 678  ./audio/trumpet\trumpet_Gs5_025_mezzo-forte_normal.mp3
# Get 679  ./audio/trumpet\trumpet_Gs5_05_forte_normal.mp3
# Get 680  ./audio/trumpet\trumpet_Gs5_05_mezzo-forte_normal.mp3
# Get 681  ./audio/viola\viola_A3_025_fortissimo_arco-normal.mp3
# Get 682  ./audio/viola\viola_A3_025_mezzo-piano_arco-normal.mp3
# Get 683  ./audio/viola\viola_A3_025_pianissimo_arco-normal.mp3
# Get 684  ./audio/viola\viola_A3_025_piano_arco-normal.mp3
# Get 685  ./audio/viola\viola_A3_05_fortissimo_arco-normal.mp3
# Get 686  ./audio/viola\viola_A3_05_mezzo-piano_arco-normal.mp3
# Get 687  ./audio/viola\viola_A3_05_pianissimo_arco-normal.mp3
# Get 688  ./audio/viola\viola_A3_05_piano_arco-normal.mp3
# Get 689  ./audio/viola\viola_A3_15_forte_arco-normal.mp3
# Get 690  ./audio/viola\viola_A3_15_fortissimo_arco-normal.mp3
# Get 691  ./audio/viola\viola_A3_15_piano_arco-normal.mp3
# Get 692  ./audio/viola\viola_A3_1_forte_arco-normal.mp3
# Get 693  ./audio/viola\viola_A3_1_fortissimo_arco-normal.mp3
# Get 694  ./audio/viola\viola_A3_1_fortissimo_pizz-normal.mp3
# Get 695  ./audio/viola\viola_A3_1_mezzo-forte_molto-vibrato.mp3
# Get 696  ./audio/viola\viola_A3_1_mezzo-piano_non-vibrato.mp3
# Get 697  ./audio/viola\viola_A3_1_pianissimo_arco-normal.mp3
# Get 698  ./audio/viola\viola_A3_1_piano_arco-glissando.mp3
# Get 699  ./audio/viola\viola_A3_1_piano_arco-normal.mp3
# Get 700  ./audio/viola\viola_A3_1_piano_pizz-normal.mp3
# Get 701  ./audio/viola\viola_A4_025_fortissimo_arco-normal.mp3
# Get 702  ./audio/viola\viola_A4_025_mezzo-piano_arco-normal.mp3
# Get 703  ./audio/viola\viola_A4_025_pianissimo_arco-normal.mp3
# Get 704  ./audio/viola\viola_A4_025_piano_arco-normal.mp3
# Get 705  ./audio/viola\viola_A4_05_forte_arco-normal.mp3
# Get 706  ./audio/viola\viola_A4_05_fortissimo_arco-normal.mp3
# Get 707  ./audio/viola\viola_A4_05_mezzo-piano_arco-normal.mp3
# Get 708  ./audio/viola\viola_A4_05_pianissimo_arco-normal.mp3
# Get 709  ./audio/viola\viola_A4_05_piano_arco-normal.mp3
# Get 710  ./audio/viola\viola_A4_15_fortissimo_arco-normal.mp3
# Get 711  ./audio/viola\viola_A4_15_pianissimo_arco-normal.mp3
# Get 712  ./audio/viola\viola_A4_15_piano_arco-normal.mp3
# Get 713  ./audio/viola\viola_A4_1_forte_arco-normal.mp3
# Get 714  ./audio/viola\viola_A4_1_fortissimo_arco-normal.mp3
# Get 715  ./audio/viola\viola_A4_1_fortissimo_snap-pizz.mp3
# Get 716  ./audio/viola\viola_A4_1_mezzo-forte_arco-major-trill.mp3
# Get 717  ./audio/viola\viola_A4_1_mezzo-forte_arco-minor-trill.mp3
# Get 718  ./audio/viola\viola_A4_1_mezzo-forte_molto-vibrato.mp3
# Get 719  ./audio/viola\viola_A4_1_mezzo-piano_non-vibrato.mp3
# Get 720  ./audio/viola\viola_A4_1_pianissimo_arco-normal.mp3
# Get 721  ./audio/viola\viola_A4_1_piano_arco-glissando.mp3
# Get 722  ./audio/viola\viola_A4_1_piano_arco-normal.mp3
# Get 723  ./audio/viola\viola_A4_1_piano_pizz-normal.mp3
# Get 724  ./audio/viola\viola_A5_1_forte_arco-normal.mp3
# Get 725  ./audio/viola\viola_A5_1_fortissimo_arco-normal.mp3
# Get 726  ./audio/viola\viola_A5_1_mezzo-forte_artificial-harmonic.mp3
# Get 727  ./audio/viola\viola_A5_1_pianissimo_arco-normal.mp3
# Get 728  ./audio/viola\viola_Ds3_05_fortissimo_arco-normal.mp3
# Get 729  ./audio/viola\viola_Ds3_05_mezzo-piano_arco-normal.mp3
# Get 730  ./audio/viola\viola_Ds3_1_piano_pizz-normal.mp3
# Get 731  ./audio/viola\viola_Gs3_025_fortissimo_arco-normal.mp3
# Get 732  ./audio/viola\viola_Gs3_025_mezzo-piano_arco-normal.mp3
# Get 733  ./audio/viola\viola_Gs3_025_pianissimo_arco-normal.mp3
# Get 734  ./audio/viola\viola_Gs3_025_piano_arco-normal.mp3
# Get 735  ./audio/viola\viola_Gs3_15_fortissimo_arco-normal.mp3
# Get 736  ./audio/viola\viola_Gs3_15_pianissimo_arco-normal.mp3
# Get 737  ./audio/viola\viola_Gs3_15_piano_arco-normal.mp3
# Get 738  ./audio/viola\viola_Gs4_025_fortissimo_arco-normal.mp3
# Get 739  ./audio/viola\viola_Gs4_025_mezzo-piano_arco-normal.mp3
# Get 740  ./audio/viola\viola_Gs4_025_pianissimo_arco-normal.mp3
# Get 741  ./audio/viola\viola_Gs4_05_fortissimo_arco-normal.mp3
# Get 742  ./audio/viola\viola_Gs4_05_mezzo-piano_arco-normal.mp3
# Get 743  ./audio/viola\viola_Gs4_05_pianissimo_arco-normal.mp3
# Get 744  ./audio/viola\viola_Gs4_05_piano_arco-normal.mp3
# Get 745  ./audio/viola\viola_Gs4_15_fortissimo_arco-normal.mp3
# Get 746  ./audio/viola\viola_Gs4_15_mezzo-piano_arco-normal.mp3
# Get 747  ./audio/viola\viola_Gs4_15_pianissimo_arco-normal.mp3
# Get 748  ./audio/viola\viola_Gs4_1_fortissimo_arco-normal.mp3
# Get 749  ./audio/viola\viola_Gs4_1_mezzo-piano_arco-normal.mp3
# Get 750  ./audio/viola\viola_Gs4_1_pianissimo_arco-normal.mp3
# Get 751  ./audio/viola\viola_Gs4_1_piano_arco-normal.mp3
# Get 752  ./audio/viola\viola_Gs5_025_forte_arco-normal.mp3
# Get 753  ./audio/viola\viola_Gs5_025_fortissimo_arco-normal.mp3
# Get 754  ./audio/viola\viola_Gs5_025_mezzo-piano_arco-normal.mp3
# Get 755  ./audio/viola\viola_Gs5_025_pianissimo_arco-normal.mp3
# Get 756  ./audio/viola\viola_Gs5_05_forte_arco-normal.mp3
# Get 757  ./audio/viola\viola_Gs5_05_fortissimo_arco-normal.mp3
# Get 758  ./audio/viola\viola_Gs5_05_pianissimo_arco-normal.mp3
# Get 759  ./audio/viola\viola_Gs5_05_piano_arco-normal.mp3
# Get 760  ./audio/viola\viola_Gs5_15_fortissimo_arco-normal.mp3
# Get 761  ./audio/viola\viola_Gs5_15_pianissimo_arco-normal.mp3
# Get 762  ./audio/viola\viola_Gs5_1_forte_arco-normal.mp3
# Get 763  ./audio/viola\viola_Gs5_1_fortissimo_arco-normal.mp3
# Get 764  ./audio/viola\viola_Gs5_1_fortissimo_snap-pizz.mp3
# Get 765  ./audio/viola\viola_Gs5_1_pianissimo_arco-normal.mp3
# Get 766  ./audio/viola\viola_Gs5_1_piano_arco-normal.mp3
# Get 767  ./audio/viola\viola_Gs6_025_forte_arco-normal.mp3
# Get 768  ./audio/viola\viola_Gs6_025_fortissimo_arco-normal.mp3
# Get 769  ./audio/viola\viola_Gs6_025_mezzo-piano_arco-normal.mp3
# Get 770  ./audio/viola\viola_Gs6_025_pianissimo_arco-normal.mp3
# Get 771  ./audio/viola\viola_Gs6_025_piano_arco-normal.mp3
# Get 772  ./audio/viola\viola_Gs6_05_forte_arco-normal.mp3
# Get 773  ./audio/viola\viola_Gs6_05_fortissimo_arco-normal.mp3
# Get 774  ./audio/viola\viola_Gs6_05_pianissimo_arco-normal.mp3
# Get 775  ./audio/viola\viola_Gs6_05_piano_arco-normal.mp3
# Get 776  ./audio/viola\viola_Gs6_15_forte_arco-normal.mp3
# Get 777  ./audio/viola\viola_Gs6_15_fortissimo_arco-normal.mp3
# Get 778  ./audio/viola\viola_Gs6_1_forte_arco-normal.mp3
# Get 779  ./audio/viola\viola_Gs6_1_fortissimo_arco-normal.mp3
# Get 780  ./audio/viola\viola_Gs6_1_pianissimo_arco-normal.mp3
# Calculated 780 Durations

# %% [markdown]
# ##### This code visualizes the distribution of audio file durations stored in the `duration` list using a histogram. The histogram is plotted with 40 bins, providing insights into the frequency distribution of different duration ranges. Additionally, it calculates and prints the average duration of the audio files, rounded to two decimal places. The visualization and average duration provide a summary of the dataset's temporal characteristics, aiding in further analysis or understanding of the audio files.

# %%
# Assuming 'duration' is already defined and filled with audio file durations
durationDist = pd.Series(np.array(duration))

# Creating the histogram
plt.figure(figsize=(10, 6))  # Added figure size for better visibility
durationDist.plot.hist(grid=True, bins=40, rwidth=0.9, color='#607c8e')
plt.title('Duration Distribution of Audio Files')
plt.xlabel('Duration [s]')
plt.ylabel('Counts')
plt.grid(axis='y', linestyle='--', alpha=0.75)  # Adjusted grid style for aesthetics
plt.show()  # Explicitly calling show to ensure the plot displays in all environments

# Calculating and printing the average duration
average_duration = np.mean(duration)
print(f"Duration average: {average_duration:.2f} seconds")
# Out:
# Duration average: 1.51 seconds

# %% [markdown]
# ##### This code segment loads a specified audio file (`files[10]`) using librosa, limiting the duration to 1 second. It then normalizes the audio data, pads or truncates it to ensure it exactly fits the desired duration, and computes the Short-Time Fourier Transform (STFT) spectrogram. The resulting spectrogram is displayed using matplotlib, with logarithmic frequency axis and time axis. Additionally, it prints the shape of the spectrogram array and plays back the audio. This provides both a visual representation of the audio's frequency content over time and allows for audio playback for further inspection.

# %%
# Load the specified audio file
y, sr = librosa.load(files[10], sr=fs, duration=1)  # Load 1 second of audio
y /= np.max(np.abs(y))  # Normalize

# Ensure the audio length is exactly 1 second
duration_in_samples = librosa.time_to_samples(1, sr=fs)
y_pad = librosa.util.fix_length(data=y, size=duration_in_samples)

# Compute STFT
y_stft = librosa.core.stft(y_pad, n_fft=n_fft, hop_length=hop_length)
y_spec = librosa.amplitude_to_db(abs(y_stft), ref=np.max)

# Plotting the spectrogram
plt.figure(figsize=(14, 8))
plt.title(f"Short-Time Fourier Transform Spectogram \n {files[10]}")
librosa.display.specshow(y_spec, sr=fs, y_axis='log', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.show()

print("Spectrogram Array Shape:", y_spec.shape)

# Playback the audio
Audio(y, rate=sr)
# Out:
# Spectrogram Array Shape: (1025, 87)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##### This code snippet performs label encoding and one-hot encoding on the categorical labels stored in the `labels` list. Firstly, it uses `LabelEncoder` from scikit-learn to encode the labels into numerical representations. Then, it applies one-hot encoding using `OneHotEncoder`, transforming the numerical labels into binary vectors. Finally, it prints the shape of the one-hot encoded labels array and an example of a one-hot encoded label. This process prepares the categorical labels for use in machine learning models that require numerical inputs.

# %%
# Assuming 'labels' is already defined and filled with your categorical data
labelencoder = LabelEncoder()
labelencoder.fit(labels)
print(len(labelencoder.classes_), "classes:", ", ".join(list(labelencoder.classes_)))
classes_num = labelencoder.transform(labels)

# One-Hot Encoding
encoder = OneHotEncoder()
onehot_labels = encoder.fit_transform(classes_num.reshape(-1, 1)).toarray()  # Producing a dense array

# Optionally, verify the shape and content of the one-hot encoded labels
print("Shape of one-hot encoded labels:", onehot_labels.shape)
print("Example of one-hot encoded label:", onehot_labels[0])
# Out:
# 8 classes: cello, contrabassoon, flute, mandolin, oboe, sax, trumpet, viola
# Shape of one-hot encoded labels: (780, 8)
# Example of one-hot encoded label: [1. 0. 0. 0. 0. 0. 0. 0.]

# %% [markdown]
# ##### This code block utilizes scikit-learn's `StratifiedShuffleSplit` to split the dataset into training and testing sets while maintaining class distribution. It then iterates over the splits and assigns the file paths and corresponding one-hot encoded labels to the training and testing sets. Debugging print statements are included to verify the sizes of the training and testing sets. Finally, assertions are used to ensure that the train and test sets are well-formed and aligned, checking that the number of files and labels match in each set. This process ensures that the dataset is properly split for training and evaluation purposes.

# %%
# Convert list of file paths to a numpy array for efficient indexing
files_arr = np.array(files)

# Prepare the stratified shuffle split
splitter = StratifiedShuffleSplit(n_splits=1, test_size=testset_size, random_state=0)
splits = splitter.split(files_arr, onehot_labels)  # Ensure onehot_labels align with files

for train_index, test_index in splits:
    train_set_files = files_arr[train_index]
    test_set_files = files_arr[test_index]
    train_classes = onehot_labels[train_index]
    test_classes = onehot_labels[test_index]

    # Debugging print statements to verify the distribution
    print(f"Training set size: {len(train_set_files)}")
    print(f"Test set size: {len(test_set_files)}")
    # Optionally, add more detailed checks or statistics here

# Ensure the train and test sets are well-formed and aligned
assert len(train_set_files) == len(train_classes), "Mismatch in train set sizes"
assert len(test_set_files) == len(test_classes), "Mismatch in test set sizes"
# Out:
# Training set size: 585
# Test set size: 195

# %% [markdown]
# ##### This function `build_model` defines a convolutional neural network (CNN) architecture using Keras Sequential API. It consists of two convolutional layers followed by batch normalization, max pooling, and dropout regularization to prevent overfitting. After the convolutional layers, there is a flattening layer followed by two fully connected dense layers with ReLU activation and another batch normalization layer. The output layer consists of 8 units corresponding to the number of classes in the dataset, with softmax activation for multi-class classification. Finally, the model is compiled with the Adam optimizer, categorical cross-entropy loss function, and accuracy metric. The input shape `(1025, 87, 1)` is specified based on the input data shape determined from the data processing step. This function encapsulates the construction and compilation of the CNN model, providing a convenient way to instantiate and compile the model with a given input shape.

# %%
def build_model(input_shape):
    model = Sequential([
        Conv2D(32, (3, 3), input_shape=input_shape, activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),

        Conv2D(64, (3, 3), activation='relu'),
        BatchNormalization(),
        MaxPooling2D((2, 2)),
        Dropout(0.25),
        
        Flatten(),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(8, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Assume input_shape is determined from your data processing step
model = build_model((1025, 87, 1))
# Out:
# c:\Users\sanke\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 1023, 85, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 1023, 85, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 511, 42, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 511, 42, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 509, 40, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 509, 40, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 254, 20, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 254, 20, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 325120)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │    20,807,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,827,720 (79.45 MB)
#  Trainable params: 20,827,400 (79.45 MB)
#  Non-trainable params: 320 (1.25 KB)

# %% [markdown]
# ## These snippets demonstrate compiling a neural network model with different optimizers in Keras.
# ##### 1. For Stochastic Gradient Descent (SGD) with momentum:
# #####    - The SGD optimizer is instantiated with specified learning rate (0.01) and momentum (0.9).
# #####    - The model is compiled using categorical cross-entropy loss, the SGD optimizer, and accuracy as the evaluation metric.
# #####
# ##### 2. For Adam optimizer:
# #####    - The Adam optimizer is instantiated with a learning rate of 0.001.
# #####    - Alternatively, you can use this optimizer by commenting out the SGD part and uncommenting the lines related to Adam.
# #####    - The model is compiled using categorical cross-entropy loss, the Adam optimizer, and accuracy as the evaluation metric.
# #####
# ##### These provide options for using either SGD with momentum or Adam optimizer while compiling the model, allowing experimentation with different optimization algorithms.

# %%
# Optimizer = Stochastic Gradient Descent with momentum
optimizer_sgd = SGD(learning_rate=0.01, momentum=0.9)  # Corrected parameter name

# Alternatively, using Adam optimizer
optimizer_adam = Adam(learning_rate=0.001)  # Corrected parameter name

# Compile with SGD
model.compile(loss='categorical_crossentropy', optimizer=optimizer_sgd, metrics=['accuracy'])

# Or compile with Adam
# model.compile(loss='categorical_crossentropy', optimizer=optimizer_adam, metrics=['accuracy'])

# %% [markdown]
# ### This function `featureGenerator` generates batches of feature vectors and corresponding labels from audio files for training a neural network model. Here's how it works:
# ##### 1. It iterates through each file in the provided list of file paths.
# ##### 2. For each file, it loads the audio data, trims silence, normalizes it, and pads it to ensure consistent length.
# ##### 3. It then computes the Short-Time Fourier Transform (STFT) spectrogram of the audio data.
# ##### 4. If augmentation is enabled, it augments the audio data by changing pitch and adding random noise.
# ##### 5. It checks if the resulting spectrogram has the correct shape (87 columns).
# ##### 6. It expands the dimensions of the spectrogram to match the input shape expected by the CNN model.
# ##### 7. It yields batches of feature vectors and corresponding labels, with each batch containing `batch_size` samples.
# ##### This generator function enables real-time data augmentation and processing, making it suitable for training deep learning models with large audio datasets.

# %%
def augment_audio(y, sr):
    # Change pitch (up or down by a half-step)
    y_pitched = librosa.effects.pitch_shift(y, sr, n_steps=np.random.randint(-1, 2))
    # Add random noise
    y_noisy = y_pitched + 0.005 * np.random.randn(len(y_pitched))
    return y_noisy

def featureGenerator(files, labels, batch_size=32, augment=False):
    while True:
        feature_vectors = []
        batch_labels = []
        for i, f in enumerate(files):
            try:
                y, sr = librosa.load(f, sr=fs)
                if len(y) < 2:
                    continue
                if augment:
                    y = augment_audio(y, sr)
                                
                y, index = librosa.effects.trim(y, top_db=60)  # Trim silence
                y = librosa.util.normalize(y)
                duration_in_samples = librosa.time_to_samples(1, sr=sr)  # Ensure this is correct
                y_pad = librosa.util.fix_length(data=y, size=duration_in_samples)
                y_stft = librosa.core.stft(y_pad, n_fft=n_fft, hop_length=hop_length)
                y_spec = librosa.amplitude_to_db(abs(y_stft), ref=np.max)
                if y_spec.shape[1] != 87:
                    continue  # Skip this sample or adjust it as needed
                data = np.expand_dims(y_spec, axis=-1)  # Ensuring correct shape for CNN input
                
                
                feature_vectors.append(data)
                batch_labels.append(labels[i])
                if len(feature_vectors) == batch_size:
                    yield np.array(feature_vectors), np.array(batch_labels)
                    feature_vectors, batch_labels = [], []
            except Exception as e:
                continue
        if feature_vectors:
            yield np.array(feature_vectors), np.array(batch_labels)

# %% [markdown]
# ### The code initializes and configures several callbacks for the Keras model training process:
#
# ##### 1. `History()`: Collects training metrics for visualization and analysis.
# ##### 2. `EarlyStopping()`: Monitors validation accuracy and stops training if it doesn't improve by at least 0.01 for 20 epochs, restoring the best weights.
# ##### 3. `ModelCheckpoint()`: Saves the best model based on validation accuracy during training.
# ##### 4. `TensorBoard()`: Sets up TensorBoard for visualization of training metrics.
# ##### These callbacks are then passed to the `fit()` method along with training and validation data generators. The training process runs for 100 epochs with a batch size of 5 for the training set and 32 for the validation set. Adjustments can be made to the batch size and other parameters as needed.

# %%
# Initialize callbacks
hist = History()
es = EarlyStopping(monitor='val_accuracy', min_delta=0.01, restore_best_weights=True, patience=20, verbose=1)
mc = ModelCheckpoint('best_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1)  # Ensure this uses .keras extension
tensorboard_callback = TensorBoard(log_dir='./logs', histogram_freq=1)  # Set up TensorBoard callback

callbacksKeras = [hist, es, mc, tensorboard_callback]  # Include TensorBoard in the list of callbacks
model.compile(optimizer=Adam(learning_rate=0.001), 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
# Model training
model.fit(featureGenerator(train_set_files, train_classes, batch_size=5),  # Adjust batch_size if needed
          validation_data=featureGenerator(test_set_files, test_classes, batch_size=32),
          validation_steps=50,
          steps_per_epoch=100,
          epochs=100,
          callbacks=callbacksKeras,
          verbose=1)
# Out:
# Epoch 1/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9798 - loss: 0.1296
# Epoch 1: val_accuracy improved from -inf to 0.21761, saving model to best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 54s 520ms/step - accuracy: 0.9797 - loss: 0.1300 - val_accuracy: 0.2176 - val_loss: 1612.5988
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9328 - loss: 0.2014
# Epoch 2: val_accuracy improved from 0.21761 to 0.57266, saving model to best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 43s 430ms/step - accuracy: 0.9329 - loss: 0.2012 - val_accuracy: 0.5727 - val_loss: 1.2610
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9423 - loss: 0.1825
# Epoch 3: val_accuracy did not improve from 0.57266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 404ms/step - accuracy: 0.9424 - loss: 0.1824 - val_accuracy: 0.5476 - val_loss: 2.3809
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9738 - loss: 0.1094
# Epoch 4: val_accuracy did not improve from 0.57266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 395ms/step - accuracy: 0.9738 - loss: 0.1095 - val_accuracy: 0.3679 - val_loss: 179.6293
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9568 - loss: 0.1647
# Epoch 5: val_accuracy did not improve from 0.57266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 384ms/step - accuracy: 0.9568 - loss: 0.1646 - val_accuracy: 0.1875 - val_loss: 22487.7852
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9687 - loss: 0.1354
# Epoch 6: val_accuracy did not improve from 0.57266
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 368ms/step - accuracy: 0.9687 - loss: 0.1356 - val_accuracy: 0.3493 - val_loss: 46.8833
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9822 - loss: 0.0941
# Epoch 7: val_accuracy improved from 0.57266 to 0.89181, saving model to best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 37s 370ms/step - accuracy: 0.9821 - loss: 0.0942 - val_accuracy: 0.8918 - val_loss: 4.2654
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9692 - loss: 0.0915
# Epoch 8: val_accuracy did not improve from 0.89181
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 381ms/step - accuracy: 0.9692 - loss: 0.0916 - val_accuracy: 0.1281 - val_loss: 35.4233
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.9669 - loss: 0.1180
# Epoch 9: val_accuracy did not improve from 0.89181
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 39s 395ms/step - accuracy: 0.9669 - loss: 0.1180 - val_accuracy: 0.6908 - val_loss: 39.7226
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.9678 - loss: 0.0953
# Epoch 10: val_accuracy did not improve from 0.89181
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 38s 377ms/step - accuracy: 0.9677 - loss: 0.0954 - val_accuracy: 0.1983 - val_loss: 96.1248
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9842 - loss: 0.0605
# Epoch 11: val_accuracy did not improve from 0.89181
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s
val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 363ms/step - accuracy: 0.9858 - loss: 0.0507 - val_accuracy: 0.1331 - val_loss: 2072.9146
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9902 - loss: 0.0401
# Epoch 31: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.9902 - loss: 0.0403 - val_accuracy: 0.3694 - val_loss: 5.5226
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9947 - loss: 0.0383
# Epoch 32: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 364ms/step - accuracy: 0.9947 - loss: 0.0382 - val_accuracy: 0.7974 - val_loss: 0.6365
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9920 - loss: 0.0310
# Epoch 33: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 366ms/step - accuracy: 0.9920 - loss: 0.0310 - val_accuracy: 0.1546 - val_loss: 740.3987
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9872 - loss: 0.0513
# Epoch 34: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.9872 - loss: 0.0512 - val_accuracy: 0.1288 - val_loss: 4467.7485
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9900 - loss: 0.0417
# Epoch 35: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 358ms/step - accuracy: 0.9900 - loss: 0.0418 - val_accuracy: 0.1330 - val_loss: 14386.5674
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9744 - loss: 0.0954
# Epoch 36: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 361ms/step - accuracy: 0.9744 - loss: 0.0952 - val_accuracy: 0.7430 - val_loss: 8.3994
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9879 - loss: 0.0410
# Epoch 37: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.9879 - loss: 0.0409 - val_accuracy: 0.4517 - val_loss: 345.6389
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9951 - loss: 0.0330
# Epoch 38: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 358ms/step - accuracy: 0.9951 - loss: 0.0330 - val_accuracy: 0.5605 - val_loss: 221.2028
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9926 - loss: 0.0298
# Epoch 39: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 359ms/step - accuracy: 0.9926 - loss: 0.0297 - val_accuracy: 0.9492 - val_loss: 0.2031
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.0137
# Epoch 40: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 360ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9320 - val_loss: 0.4193
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9994 - loss: 0.0173
# Epoch 41: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 365ms/step - accuracy: 0.9994 - loss: 0.0174 - val_accuracy: 0.4996 - val_loss: 198.3464
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9886 - loss: 0.0280
# Epoch 42: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 357ms/step - accuracy: 0.9886 - loss: 0.0280 - val_accuracy: 0.8823 - val_loss: 7.7759
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9978 - loss: 0.0183
# Epoch 43: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 359ms/step - accuracy: 0.9977 - loss: 0.0184 - val_accuracy: 0.9492 - val_loss: 0.1766
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9929 - loss: 0.0183
# Epoch 44: val_accuracy did not improve from 0.97495
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 36s 361ms/step - accuracy: 0.9929 - loss: 0.0183 - val_accuracy: 0.2341 - val_loss: 3279.5923
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 24.

# %% [markdown]
# #### This function, `plot_history(history)`, plots the training and validation loss as well as training and validation accuracy over epochs. It handles both TensorFlow and Keras versions, detecting the keys for loss and accuracy accordingly. It then plots these metrics using Matplotlib, distinguishing between training and validation data. Finally, it displays the loss and accuracy plots using `plt.show()`.

# %%
def plot_history(history):
    # Handle both possible keys for loss and accuracy depending on TensorFlow/Keras version
    loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' not in s]
    val_loss_list = [s for s in history.history.keys() if 'loss' in s and 'val' in s]
    acc_list = [s for s in history.history.keys() if any(x in s for x in ['acc', 'accuracy']) and 'val' not in s]
    val_acc_list = [s for s in history.history.keys() if any(x in s for x in ['acc', 'accuracy']) and 'val' in s]
    
    if len(loss_list) == 0:
        print('Loss is missing in history')
        return 
    
    # Assuming loss always exists
    epochs = range(1, len(history.history[loss_list[0]]) + 1)
    
    # Loss Plot
    plt.figure(1)
    for l in loss_list:
        plt.plot(epochs, history.history[l], 'b', label='Training loss' if l == loss_list[0] else None)
    for l in val_loss_list:
        plt.plot(epochs, history.history[l], 'g', label='Validation loss' if l == val_loss_list[0] else None)
    
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    # Accuracy Plot
    plt.figure(2)
    for l in acc_list:
        plt.plot(epochs, history.history[l], 'b', label='Training accuracy' if l == acc_list[0] else None)
    for l in val_acc_list:    
        plt.plot(epochs, history.history[l], 'g', label='Validation accuracy' if l == val_acc_list[0] else None)

    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# %%
plot_history(hist)

# %% [markdown]
# #### It seems that you encountered a `NameError` for `math` in the code block. To resolve this, ensure you import the `math` module at the beginning of your script. Add `import math` alongside other import statements. This will resolve the `NameError` and allow you to correctly calculate the number of steps for making predictions.

# %%
# Load the saved model
saved_model = load_model('best_model.keras')  # Use the correct path and filename

# Calculate the correct number of steps based on your batch size and total number of test files
num_test_samples = len(test_set_files)  # Make sure this is correctly calculated or set
batch_size = 32
steps = math.ceil(num_test_samples / batch_size)

# Make predictions
test_pred = saved_model.predict(featureGenerator(test_set_files, test_classes, batch_size=batch_size), steps=steps, verbose=1)
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001799C874F40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 312ms/step

# %% [markdown]
# #### This code segment first identifies the predicted class labels by finding the indices with the highest probability in the prediction array. Then, it employs the `inverse_transform` method of the `LabelEncoder` to convert these indices back into their original class labels, providing human-readable predictions for evaluation or further analysis.

# %%
# Get the indices of the max logit, which are the class labels
predictions_int = np.argmax(test_pred, axis=1)

# Use the LabelEncoder to transform these indices back to the original class labels
predictions_labels = labelencoder.inverse_transform(predictions_int)

# %%
print(len(predictions_int))
print(predictions_int)
print(len(predictions_labels))
print(predictions_labels)
print(len(classes_num[test_index]))
print(classes_num[test_index])
# Out:
# 195
# [1 1 1 6 6 0 3 7 5 6 2 0 2 5 7 3 6 3 6 0 3 1 3 6 5 4 7 0 5 6 3 7 5 7 4 5 7
#  5 2 7 5 7 5 3 3 0 4 4 4 7 6 6 1 1 3 2 1 7 6 0 0 1 0 3 6 2 2 1 1 7 1 0 4 7
#  5 0 0 7 4 2 4 2 4 3 7 7 6 7 4 4 1 2 4 0 6 6 5 7 4 0 4 4 5 7 0 7 6 2 6 5 4
#  1 1 2 3 2 1 7 2 4 0 3 2 4 6 3 5 5 1 1 1 4 2 1 2 7 7 1 4 6 5 7 2 3 5 2 2 7
#  0 6 7 4 4 0 6 0 4 1 3 2 7 5 0 5 2 0 4 7 2 3 7 5 6 7 0 5 5 2 5 4 0 6 1 6 5
#  2 1 3 6 2 3 6 0 3 7]
# 195
# ['contrabassoon' 'contrabassoon' 'contrabassoon' 'trumpet' 'trumpet'
#  'cello' 'mandolin' 'viola' 'sax' 'trumpet' 'flute' 'cello' 'flute' 'sax'
#  'viola' 'mandolin' 'trumpet' 'mandolin' 'trumpet' 'cello' 'mandolin'
#  'contrabassoon' 'mandolin' 'trumpet' 'sax' 'oboe' 'viola' 'cello' 'sax'
#  'trumpet' 'mandolin' 'viola' 'sax' 'viola' 'oboe' 'sax' 'viola' 'sax'
#  'flute' 'viola' 'sax' 'viola' 'sax' 'mandolin' 'mandolin' 'cello' 'oboe'
#  'oboe' 'oboe' 'viola' 'trumpet' 'trumpet' 'contrabassoon' 'contrabassoon'
#  'mandolin' 'flute' 'contrabassoon' 'viola' 'trumpet' 'cello' 'cello'
#  'contrabassoon' 'cello' 'mandolin' 'trumpet' 'flute' 'flute'
#  'contrabassoon' 'contrabassoon' 'viola' 'contrabassoon' 'cello' 'oboe'
#  'viola' 'sax' 'cello' 'cello' 'viola' 'oboe' 'flute' 'oboe' 'flute'
#  'oboe' 'mandolin' 'viola' 'viola' 'trumpet' 'viola' 'oboe' 'oboe'
#  'contrabassoon' 'flute' 'oboe' 'cello' 'trumpet' 'trumpet' 'sax' 'viola'
#  'oboe' 'cello' 'oboe' 'oboe' 'sax' 'viola' 'cello' 'viola' 'trumpet'
#  'flute' 'trumpet' 'sax' 'oboe' 'contrabassoon' 'contrabassoon' 'flute'
#  'mandolin' 'flute' 'contrabassoon' 'viola' 'flute' 'oboe' 'cello'
#  'mandolin' 'flute' 'oboe' 'trumpet' 'mandolin' 'sax' 'sax'
#  'contrabassoon' 'contrabassoon' 'contrabassoon' 'oboe' 'flute'
#  'contrabassoon' 'flute' 'viola' 'viola' 'contrabassoon' 'oboe' 'trumpet'
#  'sax' 'viola' 'flute' 'mandolin' 'sax' 'flute' 'flute' 'viola' 'cello'
#  'trumpet' 'viola' 'oboe' 'oboe' 'cello' 'trumpet' 'cello' 'oboe'
#  'contrabassoon' 'mandolin' 'flute' 'viola' 'sax' 'cello' 'sax' 'flute'
#  'cello' 'oboe' 'viola' 'flute' 'mandolin' 'viola' 'sax' 'trumpet' 'viola'
#  'cello' 'sax' 'sax' 'flute' 'sax' 'oboe' 'cello' 'trumpet'
#  'contrabassoon' 'trumpet' 'sax' 'flute' 'contrabassoon' 'mandolin'
#  'trumpet' 'flute' 'mandolin' 'trumpet' 'cello' 'mandolin' 'viola']
# 195
# [1 1 1 6 6 0 3 7 5 6 2 0 2 5 7 3 6 3 6 0 3 1 3 6 5 4 7 0 5 6 3 7 5 7 4 5 5
#  5 2 7 5 7 5 3 3 0 4 4 4 7 6 6 1 1 3 2 1 7 6 0 0 1 0 3 6 2 2 1 1 7 1 0 4 7
#  5 0 0 7 4 2 4 2 4 3 7 7 6 7 4 4 1 2 4 0 6 6 5 7 4 0 4 4 5 7 0 7 6 2 6 5 4
#  1 1 2 3 2 1 7 2 4 0 3 2 4 6 3 5 5 1 1 1 4 2 1 2 7 0 1 4 6 5 0 2 3 5 2 2 1
#  0 6 7 4 4 0 6 0 4 1 3 2 1 5 0 5 2 0 4 7 2 3 7 5 6 7 0 5 5 2 5 4 0 6 1 6 5
#  2 1 3 6 2 3 6 0 3 7]

# %% [markdown]
# ##### This code computes several evaluation metrics for the classification model's performance. It calculates the recall, precision, F1-score, and accuracy using functions provided by scikit-learn. The results are printed out, providing insights into the model's performance across different classes, including the overall accuracy and the number of correctly classified samples. Additionally, a comprehensive classification report is generated, offering a detailed breakdown of performance metrics for each class.

# %%
# Assuming predictions_int and classes_num[test_index] are correctly defined and contain the predicted and true labels, respectively.

# Calculate and print Recall
recall_results = recall_score(classes_num[test_index], predictions_int, average=None)
print("Recall: ", recall_results)

# Calculate and print Precision
precision_results = precision_score(classes_num[test_index], predictions_int, average=None)
print("Precision: ", precision_results)

# Calculate and print F1-Score
f1_results = f1_score(classes_num[test_index], predictions_int, average=None)
print("F1-Score: ", f1_results)

# Calculate and print Accuracy
accuracy_result = accuracy_score(classes_num[test_index], predictions_int, normalize=True)
total_correct = accuracy_score(classes_num[test_index], predictions_int, normalize=False)
print("Accuracy: %.2f, Total Correct: %d" % (accuracy_result, total_correct))
print("Number of samples:", classes_num[test_index].shape[0])

# Generate and print a full classification report
class_report = classification_report(classes_num[test_index], predictions_int)
print(class_report)
# Out:
# Recall:  [0.92 0.92 1.   1.   1.   0.96 1.   1.  ]
# Precision:  [1.   1.   1.   1.   1.   1.   1.   0.83]
# F1-Score:  [0.96 0.96 1.   1.   1.   0.98 1.   0.91]
# Accuracy: 0.97, Total Correct: 190
# Number of samples: 195
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        25
#            1       1.00      0.92      0.96        25
#            2       1.00      1.00      1.00        25
#            3       1.00      1.00      1.00        20
#            4       1.00      1.00      1.00        25
#            5       1.00      0.96      0.98        25
#            6       1.00      1.00      1.00        25
#            7       0.83      1.00      0.91        25
#
#     accuracy                           0.97       195
#    macro avg       0.98      0.97      0.98       195
# weighted avg       0.98      0.97      0.98       195

# %% [markdown]
# #### This function plots a confusion matrix, which is a visual representation of the model's performance in classifying the test data. It takes the confusion matrix `cm`, a list of class names `classes`, and optional parameters to normalize the matrix and set the title and color map. The matrix is displayed with colored cells representing the number of true positives, false positives, true negatives, and false negatives for each class.
#
# ### Function to Plot Confusion Matrix
# ##### http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(classes_num[test_index], predictions_int)
np.set_printoptions(precision=2)

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    """
    #print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Plot non-normalized confusion matrix
plt.figure(figsize=(16,12))
plot_confusion_matrix(cnf_matrix, classes=labelencoder.classes_,
                      title='Confusion matrix, without normalization')

# %% [markdown]
# ##### This code snippet creates a list `wrong_predictions` containing the indexes of samples where the predicted label does not match the true label. It iterates over pairs of true labels (`e1`) and predicted labels (`e2`) in the test set, identifying the indexes (`i`) where they differ.

# %%
# Find wrong predicted samples indexes
wrong_predictions = [i for i, (e1, e2) in enumerate(zip(classes_num[test_index], predictions_int)) if e1 != e2]

# %%
# Find wrong predicted audio files
print(np.array(labels)[test_index[wrong_predictions]])
print(predictions_labels[wrong_predictions].T)
print(np.array(files)[test_index[wrong_predictions]])
# Out:
# ['sax' 'cello' 'cello' 'contrabassoon' 'contrabassoon']
# ['viola' 'viola' 'viola' 'viola' 'viola']
# ['./audio/sax\\saxophone_Gs3_05_pianissimo_normal.mp3'
#  './audio/cello\\cello_Gs4_025_mezzo-forte_arco-col-legno-battuto.mp3'
#  './audio/cello\\cello_A3_025_mezzo-piano_arco-normal.mp3'
#  './audio/contrabassoon\\contrabassoon_A3_very-long_piano_normal.mp3'
#  './audio/contrabassoon\\contrabassoon_As1_very-long_cresc-decresc_normal.mp3']

# %%
# Extract features (e.g., MFCCs)
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
print("MFCCs Shape:", mfccs.shape)
# Out:
# MFCCs Shape: (13, 87)
